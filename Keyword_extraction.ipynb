# %%
import json, os
import pandas as pd
from nltk.corpus import stopwords
import numpy as np
from pymorphy2 import MorphAnalyzer
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
morph = MorphAnalyzer()
stops = set(stopwords.words('russian'))
from pymystem3 import Mystem
m = Mystem()

# %%
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# ## Данные

# %% [markdown]
# Возьмем данные вот отсюда - https://github.com/mannefedov/ru_kw_eval_datasets Там лежат 4 датасета (статьи с хабра, с Russia Today, Независимой газеты и научные статьи с Киберленинки). Датасет НГ самый маленький, поэтому возьмем его в качестве примера.

# %%
# скачаем данные в папке data и распакуем их
PATH_TO_DATA = './data'

# %%
files = [os.path.join(PATH_TO_DATA, file) for file in os.listdir(PATH_TO_DATA)]

# %% [markdown]
# Объединим файлы в один датасет.

# %%
data = pd.concat([pd.read_json(file, lines=True,  encoding='utf-8') for file in files][:1], axis=0, ignore_index=True)

# %%
data.shape
# Out:
# (999, 5)

# %%
data.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    content  \
# 0  Многие интересуются, зачем нужна «Яблоку» молодежная фракция? Основной задачей «Молодежного «Яблока» является привлечение молодых людей к участию в выборах и деятельности партии. «Молодежное «Яблоко» работает более чем в 10 регионах. Единого руководства у нас нет, но мы стараемся координировать свою деятельность и периодически проводим акции на федеральном уровне.\nМы ведем борьбу с обязательным воинским призывом. Военный – это профессия, а не обязанность. Молодые люди вправе сами распоряжаться своей жизнью и не терять целый год, отдавая государству «долг», который они у него не занимали. По мнению одного из ведущих специалистов в области оборонной политики Алексея Арбатова, переход на контрактную армию будет стоить лишь 2% военного бюджета.\nТакже на федеральном уровне «Молодежное «Яблоко» проводило акции за освобождение политзаключенных и против вмешательства России во внутреннюю политику Украины.\nРасскажу о московских активистах. Виктору Петрунину – 19 лет, он пришел к нам боль...
#
#                                 keywords summary  \
# 0  [яблоко, молодежь, молодежное яблоко]
#
#                                                                  title  \
# 0  "Молодежное "Яблоко": оппозиционная деятельность становится опасной
#
#                                                           url
# 0  http://www.ng.ru/ng_politics/2017-04-18/11_6976_apple.html

# %% [markdown]
# Каждой статье приписано какое-то количество ключевых слов. Допустим, что это единственно правильный набор ключевых слов (что конечно не так, но других данных у нас нет). Наша задача - придумать как извлекать точно такой же список автоматически.
# Зададим несколько метрик, по которым будем определять качество извлекаемых ключевых слов - точность, полноту, ф1-меру и меру жаккарда.

# %%
def evaluate(true_kws, predicted_kws):
    assert len(true_kws) == len(predicted_kws)
    
    precisions = []
    recalls = []
    f1s = []
    jaccards = []
    
    for i in range(len(true_kws)):
        true_kw = set(true_kws[i])
        predicted_kw = set(predicted_kws[i])
        
        tp = len(true_kw & predicted_kw)
        union = len(true_kw | predicted_kw)
        fp = len(predicted_kw - true_kw)
        fn = len(true_kw - predicted_kw)
        
        if (tp+fp) == 0:
            prec = 0
        else:
            prec = tp / (tp + fp)
        
        if (tp+fn) == 0:
            rec = 0
        else:
            rec = tp / (tp + fn)
        if (prec+rec) == 0:
            f1 = 0
        else:
            f1 = (2*(prec*rec))/(prec+rec)
            
        jac = tp / union
        
        precisions.append(prec)
        recalls.append(rec)
        f1s.append(f1)
        jaccards.append(jac)
    print('Precision - ', round(np.mean(precisions), 2))
    print('Recall - ', round(np.mean(recalls), 2))
    print('F1 - ', round(np.mean(f1s), 2))
    print('Jaccard - ', round(np.mean(jaccards), 2))

# %% [markdown]
# Проверим, что всё работает как надо.

# %%
evaluate(data['keywords'], data['keywords'])
# Out:
# Precision -  1.0
# Recall -  1.0
# F1 -  1.0
# Jaccard -  1.0

# %% [markdown]
# # Тупое решение.

# %% [markdown]
# Давайте не будем думать, а попробуем сразу придумать какое-то решение.

# %% [markdown]
# Возьмем первые 5 слов из заголовка.

# %%
evaluate(data['keywords'], data['title'].apply(lambda x: x.lower().split()[:5]))
# Out:
# Precision -  0.06
# Recall -  0.06
# F1 -  0.06
# Jaccard -  0.03

# %% [markdown]
# Или 10.

# %%
evaluate(data['keywords'], data['title'].apply(lambda x: x.lower().split()[:10]))
# Out:
# Precision -  0.06
# Recall -  0.07
# F1 -  0.06
# Jaccard -  0.03

# %% [markdown]
# Теперь попробуем взять самые частотные слова.

# %%
evaluate(data['keywords'], data['content'].apply(lambda x: 
                                                 [x[0] for x in Counter(x.lower().split()).most_common(10)]))
# Out:
# Precision -  0.02
# Recall -  0.04
# F1 -  0.02
# Jaccard -  0.01

# %% [markdown]
# Или вообще рандомные слова.

# %%
evaluate(data['keywords'], data['content'].apply(lambda x: 
                                                 np.random.choice(list(set(x.lower().split())), 10)))
# Out:
# Precision -  0.0
# Recall -  0.01
# F1 -  0.01
# Jaccard -  0.0

# %% [markdown]
# Теперь давайте посмотрим, что вообще извлекается.

# %%
data['title'].apply(lambda x: x.lower().split()[:10]).head(10)
# Out:
# 0                         ["молодежное, "яблоко":, оппозиционная, деятельность, становится, опасной]
# 1                                                                 ["газпрома", на, всех, не, хватит]
# 2                                                   [бесконечная, партия, в, четырехмерные, шахматы]
# 3    [экс-депутат,, осужденная, за, фальсификацию, выборов,, оказалась, членом, "боевого, братства"]
# 4                               [новая, москва, останется, территорией, экологической, безопасности]
# 5                                [f1., гран-при, сша, прошел, без, четырех, машин, и, со, «стопкой»]
# 6                                          [100, ведущих, политиков, россии, в, феврале, 2018, года]
# 7                                               [закон, "о, культуре", принимают, на, фоне, арестов]
# 8                                    [насколько, реальна, газовая, подоплека, сирийского, конфликта]
# 9                                  [фсб:, в, калужской, области, задержаны, четверо, участников, иг]
# Name: title, dtype: object

# %%
data['content'].apply(lambda x: [x[0] for x in Counter(x.lower().split()).most_common(10)]).head(10)
# Out:
# 0                                                      [в, и, на, не, что, –, его, «молодежное, с, это]
# 1                                                            [в, и, на, –, млрд., куб., по, к, газа, м]
# 2                                                                 [в, –, и, не, я, но, что, это, на, с]
# 3                                                       [в, на, и, ким, по, –, что, видео, он, зинаиды]
# 4                                              [в, и, на, новой, площадью, москвы, –, развития, с, для]
# 5                                                             [в, на, и, не, с, но, уже, что, у, гонки]
# 6                                                  [на, в, (с, место)., и, рф, позиции, влияние, по, с]
# 7                                                        [в, и, –, по, с, культуре, не, из, будет, как]
# 8                                                              [в, и, на, с, что, для, по, –, не, газа]
# 9    [в, рф, террористической, организации, задержаны, –, четверо, участников, запрещенной, «исламское]
# Name: content, dtype: object

# %% [markdown]
# Когда извлекаются частотные слова, то список почти полностью состоит из всяких стоп-слов. Также из-за плохой токенизации некоторые слова в обоих списках - пунктуация или слова с пунктуацией на концах. К тому же извлекаемые слова ненормализованы, а правильные ключевые слова - наоборот.

# %% [markdown]
# ## Токенизация, удаление стоп-слов и нормализация.

# %%
from string import punctuation
from nltk.corpus import stopwords
punct = punctuation+'«»—…“”*№–'
stops = set(stopwords.words('russian'))

def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0].normal_form for word in words if word and word not in stops]

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
data['title_norm'] = data['title'].apply(normalize)

# %%
data['title_norm'].head(10)
# Out:
# 0            [молодёжный, яблоко, оппозиционный, деятельность, становиться, опасный]
# 1                                                                 [газпром, хватить]
# 2                                      [бесконечный, партия, четырехмерный, шахматы]
# 3    [экс-депутат, осудить, фальсификация, выбор, оказаться, член, боевой, братство]
# 4                 [новый, москва, остаться, территория, экологический, безопасность]
# 5                         [f1, гран-при, сша, пройти, четыре, машина, стопка, штраф]
# 6                                [100, ведущий, политик, россия, февраль, 2018, год]
# 7                                           [закон, культура, принимать, фон, арест]
# 8                     [насколько, реальный, газовый, подоплёка, сирийский, конфликт]
# 9                       [фсб, калужский, область, задержать, четверо, участник, иго]
# Name: title_norm, dtype: object

# %% [markdown]
# Попробуем те же самые методы.

# %%
# топ 10 частотных слов статьи
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.11
# Recall -  0.22
# F1 -  0.14
# Jaccard -  0.08

# %% [markdown]
# ***Эксперимент 1***
# Используем лемматизацию от mystem вместо pymorphy

# %%
# m = Mystem(mystem_bin='C://path_to_preloaded/mystem.exe')

# %%
def normalize2(text):    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [m.lemmatize(word) for word in words]
    words = [word[0] for word in words if word]
    return words

# %%
a = normalize2("Колобок, съел лису?")
a
# Out:
# ['колобок', 'съедать', 'лиса']

# %% [markdown]
# Само по себе работает. Но когда запускаем (неважно подавая пословно или по предложениям), работа mystem никогда не завершается. Видно, что по каждому вызову создается отдельный процесс mystem.exe, после чего закрывается. Естественно, что это очень медленно.

# %%
data['content_norm2'] = data['content'].apply(normalize2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-f0cf46fd384f> in <module>()
# ----> 1 data['content_norm2'] = data['content'].apply(normalize2)
#
# c:\python36\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-62-71c32090ac27> in normalize2(text)
#       1 def normalize2(text):
#       2     words = [word.strip(punct) for word in text.lower().split()]
# ----> 3     words = [m.lemmatize(word) for word in words]
#       4     words = [word[0] for word in words if word]
#       5     return words
#
# <ipython-input-62-71c32090ac27> in <listcomp>(.0)
#       1 def normalize2(text):
#       2     words = [word.strip(punct) for word in text.lower().split()]
# ----> 3     words = [m.lemmatize(word) for word in words]
#       4     words = [word[0] for word in words if word]
#       5     return words
#
# c:\python36\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     248         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     249
# --> 250         infos = self.analyze(text)
#     251         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     252
#
# c:\python36\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     233         result = []
#     234         for line in text.splitlines():
# --> 235             result.extend(self._analyze_impl(line))
#     236         return result
#     237
#
# c:\python36\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     296             self._procin.write(_NL)
#     297
# --> 298             out, _ = self._proc.communicate()
#     299             self._proc = None
#     300             try:
#
# c:\python36\lib\subprocess.py in communicate(self, input, timeout)
#     841
#     842             try:
# --> 843                 stdout, stderr = self._communicate(input, endtime, timeout)
#     844             finally:
#     845                 self._communication_started = True
#
# c:\python36\lib\subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1090             # calls communicate again.
#    1091             if self.stdout is not None:
# -> 1092                 self.stdout_thread.join(self._remaining_time(endtime))
#    1093                 if self.stdout_thread.is_alive():
#    1094                     raise TimeoutExpired(self.args, orig_timeout)
#
# c:\python36\lib\threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# c:\python36\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# **Результат 1: неудачно**

# %% [markdown]
# ***Эксперимент 2***
# Используем модуль multi-rake, для которого декларируется поддержка русского языка

# %%
from multi_rake import Rake

rake = Rake(
    min_chars=3,
    max_words=2,
    min_freq=1,
    language_code='ru',  # 'en'
    stopwords=stops,  # {'and', 'of'}
    lang_detect_threshold=50,
    max_words_unknown_lang=2,
    generated_stopwords_percentile=80,
    generated_stopwords_max_len=3,
    generated_stopwords_min_freq=2,
)

# %%
#keywords = rake.apply(text, text_for_stopwords=other_text)
def lel(txt):
    print(txt)
    return
data['content_norm_text'] = data['content_norm'].apply(" ".join)

# %%
data['content_rake'] = data['content_norm_text'].apply(rake.apply)

# %%
data['content_rake']
# Out:
# 0                                                                                                                                  []
# 1                                                                                                                                  []
# 2                                                                                                         [(огорчительный факт, 4.0)]
# 3                                                                                                                                  []
# 4                                                                                                                                  []
# 5                                                                                     [(феттель вместе, 4.0), (перес результат, 4.0)]
# 6                                                                                                                                  []
# 7                                                                                                              [(д разработать, 4.0)]
# 8                                                                                       [(heise, 1.0), (намерение, 1.0), (план, 1.0)]
# 9                                                                                                                                  []
# 10                                                                                                                                 []
# 11                                                                                                                       [(5–1, 1.0)]
# 12                                                                                                                                 []
# 13                                                                                    [(план жюри, 4.0), (вынужденный общаться, 4.0)]
# 14                                                                                                                                 []
# 15                                                                                                                                 []
# 16                                                                                                                                 []
# 17                             [(половина 2016-го, 4.0), (кобальт четыре, 4.0), (1 миллион, 1.0), (6 миллион, 1.0), (3 миллион, 1.0)]
# 18                                                                                                                  [(победный, 1.0)]
# 19                                                                                                                                 []
# 20                                                                                                                                 []
# 21                                                                                                     [(осуществлять контроль, 4.0)]
# 22                                                                     [(двоить семьдесят, 4.0), (стоять, 1.0), (месторождение, 1.0)]
# 23                                                                                                                                 []
# 24                                                                                                                                 []
# 25                                                                                                                                 []
# 26                                                                                                        [(5–2, 1.0), (страна, 1.0)]
# 27                                                                                                                                 []
# 28                                                                                 [(военный интервенция, 4.0), (полоса рейган, 4.0)]
# 29                            [(радоваться наблюдать, 4.0), (несправедливость, 1.0), (просто, 1.0), (свободный, 1.0), (сальери, 1.0)]
#                                                                     ...
# 969                                                                                                                                []
# 970                                                                                                 [(соотношение использовать, 4.0)]
# 971                                                                                                                                []
# 972                                                                                                                                []
# 973                                                                                                                                []
# 974                                                                                                                                []
# 975                                                                                                                                []
# 976                                                                                                                                []
# 977                                                                                                                    [(равно, 1.0)]
# 978                                                                                                                                []
# 979                                                                                                               [(претендент, 1.0)]
# 980                                                                                                                                []
# 981                                                                                                                    [(вести, 1.0)]
# 982                                                                                [(голландия проявиться, 4.0), (обмениваться, 1.0)]
# 983                                                                                                            [(станиславский, 1.0)]
# 984       [(управляться мир, 4.0), (немногий описание, 4.0), (сайт gefter, 4.0), (гражданский ценность, 4.0), (формула который, 4.0)]
# 985                                                                                                                                []
# 986                                                                                                                                []
# 987                                                                                                   [(обращение опубликовать, 4.0)]
# 988                                                                                                                                []
# 989                                                                                                         [(участник картель, 4.0)]
# 990                                                                                                                                []
# 991                                                                           [(программа который, 4.0), (предоставить человек, 4.0)]
# 992                                                                                                                                []
# 993                                                                                                  [(сторона, 1.0), (обидный, 1.0)]
# 994                                                                                                                                []
# 995                                                                                  [(решать делать, 4.0), (образ посредством, 4.0)]
# 996    [(ухо стоялый, 4.0), (слово плохой, 4.0), (анекдот рассказывать, 4.0), (8–11 страница, 4.0), (сердце голов, 4.0), (снег, 1.0)]
# 997                                                                                                                   [(страна, 1.0)]
# 998                                  [(модель управление, 4.0), (очередь, 1.0), (пересилить, 1.0), (оставаться, 1.0), (манящий, 1.0)]
# Name: content_rake, Length: 999, dtype: object

# %% [markdown]
# ***Вывод***: результат ужасный
# **Результат 2: неудачно**

# %% [markdown]
# ***Эксперимент 3***
# NLTK Rake

# %%
from rake_nltk import Metric, Rake as NltkRake

nRake = NltkRake(language='russian', stopwords=stops, min_length=1, max_length=2) 

def procRake(txt):
    # print(txt +"\n")    
    nRake.extract_keywords_from_text(txt)
    if nRake:
        print(nRake.get_ranked_phrases())
    return nRake.get_ranked_phrases()

# %% [markdown]
# **Пробуем NLTK Rake по нормализованным текстам**

# %%
data['content_norm_text'].apply(procRake)
# Out:
# []
# ['вр новатэк']
# ['хороший довольный', 'семья говорящий', 'русски плохо', 'огорчительный факт', 'россия', 'писать', 'метр']
# []
# ['гигант спортивно']
# ['феттель вместе', 'перес результат', 'авария спровоцировать', 'пит', 'лейный']
# ['ть 82', 'российский торгово', 'е место', 'го 98', 'го 96', 'го 92', 'го 9', 'го 86', 'го 83', 'го 8', 'го 78', 'го 77', 'го 76', 'го 74', 'го 72', 'го 71', 'го 68', 'го 66', 'го 63', 'го 62', 'го 61', 'го 60', 'го 58', 'го 56', 'го 53', 'го 48', 'го 46', 'го 45', 'го 43', 'го 42', 'го 41', 'го 40', 'го 38', 'го 3', 'го 29', 'го 20', 'го 15', 'го 11']
# ['д разработать']
# ['центр russia', 'издание www', 'зенитный комплекс', 'российско', 'план', 'намерение', 'heise']
# []
# ['половинка термо', 'неподцензурный город', 'банка бросить', 'таблетка', 'старший', 'садиться']
# ['метр 2020', '6']
# []
# ['сахалинск москва', 'план жюри', 'вынужденный общаться', 'е', '40']
# ['авторы']
# []
# []
# ['половина 2016', 'поколение 85', 'кобальт четыре', '6 миллион', '3 миллион', '1 миллион', '1', 'литий', 'го', 'би']
# ['ть', 'победный']
# []
# []
# ['осуществлять контроль', 'эз']
# ['ленин 26', 'двоить семьдесят', 'стоять', 'мини', 'месторождение']
# ['00']
# []
# []
# ['промышленный геотермально', 'страна', 'hdr']
# []
# ['член g', 'полоса рейган', 'надежда ждать', 'военный интервенция', 'айлёнда впереди', 'эн']
# ['третей меж', 'радоваться наблюдать', 'авто конёк', 'диагноз сальери', 'сальери', 'свободный', 'просто', 'несправедливость']
# ['рукбан эт']
# ['процесс материально']
# []
# ['экономический параметр', 'генерал м', '2 метр', 'магистраль', 'бернштейн']
# ['лирический']
# ['учить распределять', 'акцентировать внимание', 'очередь', 'опубликовать', 'наблюдатель']
# ['общий меж', 'кутерьма жаль']
# ['ти предмет', 'е место', 'оказаться санкт', 'санкт']
# ['убедительный объяснение']
# []
# ['отрицательный вяло', 'го год', 'хеппи']
# ['исследовательский опытно', 'пек']
# ['2016 рио', 'план', 'де']
# []
# ['дневный атака', 'el 03', '8 писатель', '9909857', '94282', '93381', '815', '7117', '6614', '5', '4444', '360', '2', '09', '0790']
# ['мировой война', 'броском марс']
# []
# []
# ['хафса аль', 'смертник аль', 'каидовский употребить', 'каида основа', 'дуджаны аля', 'бригада аба', 'право', 'первых', 'мисри', 'место', 'вторых']
# ['5', '47']
# ['лондон', 'би']
# ['время']
# ['место находиться']
# []
# []
# ['либо', 'би']
# ['свойственный']
# ['ть', 'победный']
# ['объём']
# ['го 4']
# []
# ['франциско 11', 'йорк 15', 'привыкнуть']
# ['би', 'ru', 'ng_energiya', 'ng', '9_7114_climat', '2017', '14', '11']
# ['этаж терминал', 'тип 19', 'пора пока', '300 29', 'круг', 'известный']
# ['сущность который', 'вход подъезд', 'человек', 'пребывание']
# ['тихий размеренно']
# []
# ['е год', 'вдовый голосистый', 'ха']
# ['этап 14', 'этап 1', 'ха 1991', 'половина 2015', 'го значение', '9 55', '9 35', '8 0', '4 второе', '4 1993', '4 1992', '4 12', '3 1993', '3 1992', '0 55', '0 54', '0 35', 'метр 9', 'метр 12', 'метр 11', 'метр 10', '5 49', '5 40', '7 34', 'метр', '5', '7', 'показатель', 'образ']
# []
# ['центр колл', 'мочь']
# ['вр часть']
# ['сайт би', 'би']
# ['поэт отвечать', 'общефилософский план', 'голодный весна', 'бурый руинно', 'мета']
# ['доминго тома']
# ['объём']
# ['таки присоединиться', 'проголосовать']
# ['заправщик mq', 'заправщик kc', '52 b', '1 b', 'шесть', 'снаряд', 'бригада', 'a']
# []
# ['карта однако', '9 3', '6 12', '6', 'регион']
# []
# []
# ['попытка устроить', 'лопух могила', 'искренний помирать', 'интеллектуал слово', 'верующий многие', 'близкий религия', 'похожий', 'получить', 'мешать']
# []
# ['подтверждение состав', 'говорить указывать', 'фигурант', 'римско', 'бумага']
# ['8 24', '6 42', '0 30', '2 2015', '2', 'н']
# ['полоса превратиться', 'образ покинуть', 'стометровка стоять', 'стометровка преодолевать', 'охранник бежать', 'стометровка', 'бежать', 'пропуск', 'право', 'помиловать', 'ага']
# []
# ['растить дальнейший']
# ['82', '02']
# ['черкесия кабардино']
# ['2020 год', 'платить']
# ['мировой масштаб', '5 миллиард']
# ['е 80']
# ['пустяк увидеть', 'двадцать год', 'восток туда', 'рим']
# []
# ['нехватка финансирование', 'молчать май', 'воевать молдова', 'пассивный', 'вместе']
# ['энергоблок ввэр', '1200 который', 'сися', 'говорить']
# ['02']
# ['премьер']
# []
# ['сахалинск москва', 'план жюри', 'вынужденный общаться', 'е', '40']
# ['штурмовой 81', 'ть 92', 'ть 30', 'десантно']
# ['русский блондинка', 'подойти', 'золото']
# []
# ['осуществлять контроль', 'эз']
# ['секс', 'радовать']
# ['ха год', 'страна демонстрировать', 'приватизация приниматься', 'негативный процесс', 'позиция', '6']
# []
# []
# ['поручение президент', 'неделя']
# ['сборный российско', 'канадец 7', 'центрфорвард', 'забыть', '6', '1']
# ['сторона текст', 'разному восприниматься']
# ['половина 1950', 'кот который', 'е', '06']
# []
# []
# []
# ['шейх санкт', 'ш 34', '95мс ту', '183 град', '161 град', '160 ту', 'эш', 'укрывательство']
# ['эпоха представлять']
# ['тема являться']
# ['танфа ждать', 'судьба юго', 'эз', 'день']
# ['метр 910', '45', '2017', '2']
# ['вид']
# []
# []
# ['показатель', 'п']
# []
# ['петербург']
# []
# ['женщина']
# ['ресурс publika']
# ['экономика страна', 'транзит связанный', 'статья 2', 'поведение цель', '2021 год', '17 622', '14 226', 'экспорта', 'импорт', '4552']
# ['тур']
# ['человек посчитать', 'порядок против', 'ошибка программа', 'орган чувство', 'физик', 'тело', 'ждать']
# ['зона']
# ['даун именно', 'шпион']
# ['документ']
# []
# ['пазуха']
# ['содер это', 'получиться']
# []
# ['критерий шесть', '9 егэ']
# []
# ['часть']
# []
# ['8 ми', '8', '8мтв', '5', '17в']
# []
# []
# ['мерседес разуметься', '1 победа', 'команда']
# ['срок премьер', 'передовой страна']
# ['тема подсказывать', 'мишень сосредоточить']
# ['страна народ']
# []
# ['рестарт', 'кара', 'гран', 'выйти']
# ['р недолго']
# ['секретарь экс']
# []
# ['конференция международно', 'недра']
# ['24 м', '23 м', '20']
# []
# ['энергоблок ввэр']
# ['01']
# []
# []
# ['страна россия', 'пора пока', 'завет который']
# ['подчинить']
# ['процесс материально']
# []
# []
# []
# []
# []
# []
# []
# ['нужный двадцать', 'карта вроде', 'восток северо', 'дорога']
# ['факт', 'муж']
# ['избирательный округа']
# []
# []
# ['страна обретение', 'политический научно', 'государство nation', '4 14', 'родитель', 'проблема', 'отъезд', 'возможность']
# ['бобслейный трасса']
# []
# ['слушай дед', 'небо пронестись', 'жизнь прохор', 'сторона', 'понять', 'заговорить']
# ['турецк скорее', 'российский оккупант', 'спрятаться', 'подружка', 'итальянск']
# []
# []
# []
# ['01 strsljen', 'посадка x', 'посадка', 'x', '01', 'х']
# []
# ['уделять внимание', 'ответ знать']
# []
# ['год']
# ['принимать чей', 'другому']
# ['метр', 'динамик']
# ['мститель противостояние']
# []
# []
# ['com']
# ['результат 1', 'экология', 'пришелец']
# []
# ['обходиться содержание', 'поступать']
# []
# ['мера пройти', 'масштаб']
# ['сторона проблема', 'половина послезавтра']
# []
# ['премьер']
# ['шаг', 'поставить']
# []
# ['вертолёт ми', 'прекратить', 'истребитель']
# ['важный основа', 'el 15', 'утверждение', '03']
# ['российский столица']
# ['предвыборный пресс', 'конференция пресс', 'сторона', 'образцово']
# ['версия сказать']
# ['аналитик регион']
# ['ион', 'гидроксид']
# ['метр 1996', '3 всё', '2012 65', 'первых', 'город', '52']
# ['страна обретение', 'политический научно', 'государство nation', '4 14', 'родитель', 'проблема', 'отъезд', 'возможность']
# ['еврозона сказать']
# ['шпион р', 'санкция принять']
# ['читатель подумать', 'сразу махаться', 'либо идеи', 'явление']
# ['таки немножко', 'спросить сделать', 'си среди', 'tv твц', 'би']
# ['вице']
# ['психология', 'вторых', 'вестись']
# ['технический фабрично', 'словарь точно', 'русский словарь', 'ресурс зависеть', 'ожегов н', 'н ушаков', 'мировой война', 'лексикограф слово', 'е год', 'геофизик рассматриваться', 'электронизация', 'че', 'медаль', 'брокгауз']
# ['стоялый']
# ['технология пример', 'модель россия']
# ['регион']
# ['форма разума', 'жизнь переселиться', 'создать', 'либо']
# ['цезский народ', 'половина 90', 'половина 1990', 'горный селение', 'балкария карачаево', 'российско', 'андо']
# []
# ['убедительный объяснение']
# ['2017 164']
# ['е место', '12 июль']
# []
# ['вице']
# []
# ['3 сахалин', '21 миллиард', '2 миллиард', 'французско', 'т', 'н', 'итальяно', '18']
# ['планировать']
# ['хороший довольный', 'семья говорящий', 'русски плохо', 'огорчительный факт', 'россия', 'писать', 'метр']
# ['попытка 96', 'непохожий открывать', 'вблизи видно', 'человек', 'отличный']
# []
# ['кандидат', 'день']
# []
# ['8']
# ['особенный элитный', 'легенда давным', 'выходить пробежка']
# []
# []
# ['ресурс publika']
# ['гражданин ожидать']
# []
# ['му']
# ['страна']
# ['строчка 10', 'место 13', '9 порошенко', '8 премьер', 'голосовать']
# ['издательство подумать', '17 нг', 'нг', 'самый', 'невероятный', 'казаться', 'аннотация', '12']
# []
# []
# ['этап 14', 'этап 1', 'ха 1991', 'половина 2015', 'го значение', '9 55', '9 35', '8 0', '4 второе', '4 1993', '4 1992', '4 12', '3 1993', '3 1992', '0 55', '0 54', '0 35', 'метр 9', 'метр 12', 'метр 11', 'метр 10', '5 49', '5 40', '7 34', 'метр', '5', '7', 'показатель', 'образ']
# ['сырьевой биржа', 'йорк санкт']
# ['подмосковье красно', 'тайм это', 'тайм', 'англо']
# []
# ['экология']
# ['получаться песня', 'музыка явно', 'научно']
# ['электрика посмотреть', 'ть 14', 'стоп 15', 'машина 21', 'единственный пит', 'пит', 'стопа', 'росберг', 'риска', 'грабли']
# ['12']
# ['республика корея', '3 2017', 'ниже', '5']
# ['учёный урфа']
# ['2014 вопрос']
# []
# ['ректор санкт']
# ['экс']
# ['челябинск шико', 'el 08', 'считать', '9953', '9908456', '98697', '982893', '93381', '5', '377', '368', '17', '1', '06', '0529']
# ['обряд']
# ['новый условие', 'нефть добывать', 'ненецкий округ']
# ['образ']
# ['сися избранный', 'го']
# ['цвить юго', 'цвить гарф', '07', '03']
# []
# ['вещь научиться', 'е']
# ['требовать музыкант', 'симфония финал', 'рецензия прочесть', 'проект продолжаться', 'валторнист казанский', 'моральный', 'жизнь', 'время']
# ['камера рор', '18 av', 'электронный ик', 'ик', 'электронной', 'военно', 'бла', 'ucas', 'and', 'a']
# ['место учёба', 'спорый', 'ru', 'mos']
# ['стопа ф', 'неделя аба', 'лейн вероятно', 'гонка гран', 'даби победа', 'даби', 'энд', 'мерседесовец', 'дать']
# ['социально']
# ['территория занимать', 'страна вторгаться', 'страна аннексировать', 'кроме миротворец', 'би']
# ['конкурент']
# []
# ['система который']
# ['первых ес', 'зес', 'вторых']
# ['важный основа', 'el 15', 'утверждение', '03']
# []
# []
# ['ступенька подиум', 'метр место', 'гонка выиграть', 'процедура', 'прийти']
# ['стать пьедестал']
# ['рождение одетта', 'преимущество балерина', 'одиллия главный', 'французско', 'спектакль', 'либо', 'говорить']
# []
# []
# ['присоединиться']
# ['сибвами инженерно', 'магниевый институт']
# ['обозримый будущее']
# ['порядок зальцбургринг', 'который занимать', 'ехать хонда', 'гонка 10', 'го 10', 'лейн', '11']
# ['ракетный комплекс', '95мс ту', '24 ми', '160 ту']
# ['человек человек', 'новое это', 'дух высказаться']
# ['лутовиново']
# ['период 2016', 'го отношение', 'центр', 'вице']
# ['стимулировать рост', 'платить гражданин', 'перестройка нужный', '21 22', 'считать', 'ржавый']
# []
# []
# []
# ['интерпретация минска', 'год пресс', 'step сурков', 'by']
# ['политический интернет']
# ['больший претендовать']
# ['насилие подрывать', 'идея являться', 'коллега']
# []
# ['поэт отвечать', 'общефилософский план', 'голодный весна', 'бурый руинно', 'мета']
# []
# ['эмигрант']
# ['26']
# ['hа']
# ['мартановский ачхой', 'женщина 15']
# []
# []
# []
# []
# []
# ['нал сто', '91187', '906980', '88972', '5', '4465', '292', '24', '1634', '012']
# []
# ['мнение покойный', 'слово']
# ['11 2011', '9908585', '9691', '9676', '91671', '766', '7', '5', '227', '1675', '0846', '07747']
# ['тренировочный поисково', '334 ту', '27 вертолёт', '2006 год', '204', '2']
# ['01 strsljen', 'посадка x', 'посадка', 'x', '01', 'х']
# []
# ['голосовать киев']
# ['е год', 'вдовый голосистый', 'ха']
# ['вице']
# ['отчаянный пережим', 'петербург']
# ['продажа', 'государство']
# ['депутат обвинять']
# ['первых быстро', 'редакция']
# ['8 2016', '8 2014', '7 7', '5 2015', '4 13', '4 12', '2 2015', '1 2016', 'метр 7', 'метр 5', 'метр 15', 'метр', 'вице']
# ['использовать результат']
# ['поверхность х', 'площадь дизель', 'бомбардировщик су', '555 х', '500с инерциально', '25 су', '24пн ми', 'би', '52']
# ['центр russia', 'издание www', 'зенитный комплекс', 'российско', 'план', 'намерение', 'heise']
# ['процесс внутри', 'заключить договорённость', 'хау']
# []
# ['пг', 'мон', '08', '073']
# ['осуществлять контроль', 'эз']
# []
# ['именно средство', 'вынудить ввести', '2 1166', 'расширение']
# ['добавить']
# []
# []
# []
# ['попытка 96', 'непохожий открывать', 'вблизи видно', 'человек', 'отличный']
# []
# ['обстоятельство']
# ['ха год', 'часть', 'тахрир']
# []
# ['управлять страна', 'метр']
# ['завысить послабить']
# []
# ['утверждать']
# ['столица направление', 'вице']
# ['читаться конспект', 'читательский радость', 'оригинальный это', 'жизнь сохранение', 'го стать', 'важный причина', 'коренной книга', 'архетипический книга', 'книга', 'глотаться']
# ['колоссальный']
# []
# []
# ['губернаторов', 'вице']
# ['результат 1']
# []
# ['ха год', 'пропагандист стать', 'младший будущее', 'метр 80', 'метр 60', 'втянутый многие', 'участник', 'лидер', '50']
# ['образ видеть', 'либо писать', 'строчка', 'основание']
# []
# ['исследовательский опытно', 'пек']
# []
# ['государство иерусалим']
# ['поспособствовать']
# []
# ['исследовательский опытно', 'пек']
# ['ракета 1', 'х', '12']
# []
# []
# ['нефть 66', 'нефть 3', 'нефть 10', '652 миллиард', 'сомнение', 'проект', 'мар', '6']
# ['ха 90', 'ха 80', 'ха 70', 'д прямо', 'время 21', 'танцевально']
# []
# []
# ['семья говорить', 'месяц', 'математик', 'го']
# ['центр гольф']
# ['четыре богословско', 'принадлежать ваххабитам']
# []
# []
# ['проблема юнеско', 'литва считать', 'случай', 'именно']
# ['художник', 'спец']
# []
# []
# ['пора топ']
# ['хорошему несовременный']
# ['выдающийся художник']
# []
# ['факто декоративно', 'ватиканский собор', 'братски']
# []
# []
# ['секс', 'радовать']
# ['сися июнь', 'муслимона брат']
# []
# ['сися избранный', 'го']
# ['8']
# []
# ['эпоха представлять']
# ['назвать премьер', 'год 100']
# ['принимать пища', 'статья', 'причина', 'назначить', 'год']
# ['el 27', '0 нг', '9953', '9909713', '91187', '906980', '54', '5', '302', '301', '227', '2', '07516', '0492', '04']
# ['пазуха']
# ['сапропелевый добывать', 'салымское вехне', 'летний юбилей']
# ['это учитывать']
# ['рюмашка друг', 'литр разобраться']
# ['го']
# ['поступить премьер', 'вторых']
# ['шикотанский']
# []
# ['пропеть каждый', 'фай', 'иуда']
# ['это']
# ['пушка отлить', 'камнерезный фабрика', 'уцелеть']
# ['правовой измерение', 'дипломатичний шлях', 'контингент']
# ['нужный', 'ага']
# []
# ['war21', 'article']
# ['объект объект', 'зверь поп', 'формально', 'представлять', 'де']
# ['очередь бизнес', 'иной бизнес']
# []
# ['процесс материально']
# ['кво увериться']
# ['чистый зато', 'половина 1930', 'д это', 'голосовать выборы']
# ['книжный ярмарка', 'el 02', '11']
# ['п']
# ['бронхит']
# ['фильм']
# ['час 4', 'час 3', 'час 2', 'час 1', 'час 0', '8 0', '6 0', 'час 5', '5']
# []
# ['ответ уволить', 'го 22']
# ['день']
# ['2020 год', '17 870', '1 173', '05']
# ['стартовый ряд', 'стартовый место', 'соревнование состоять', 'свой пилот', 'поул поздний', 'й 10', 'е 16', 'гоночный уик', 'экстраординарный', 'разбитый', 'машина']
# ['установка привести', 'правовой договор', 'относить прекариат', 'е год', 'показной']
# ['donoghues']
# []
# ['составить около']
# ['осуществлять контроль', 'эз']
# ['австралиец']
# ['формула e', 'сегодня 77']
# ['технология качество', 'технологический социально', 'п х', 'наука х', 'направление х', 'информатика х', 'вычисление х', 'гигант', '02']
# ['восточный дейр', 'эз', 'северо']
# ['02']
# ['стоить особняком', 'расстройство', 'время']
# ['лист 6', 'направление', 'a']
# []
# ['тонна ожидаться', 'конференция президент', '170']
# ['теоретик м', 'ландау']
# ['хсс социал']
# ['москва смочь', '1']
# ['книга']
# []
# ['фронтовик рассказ', 'ингушский население', 'ингушетия таковой', 'ингушетия кабардино', 'д т']
# ['ценный порода', 'закон закон', '5 тысяча', '3 миллиард']
# []
# []
# ['совратить мальчик', 'снимать общий', 'жертва священник']
# ['намдо северо']
# []
# ['д т', 'государственный элита', 'го 2010']
# ['химия создать', 'слово который', 'известный ранее', '2 новичок', '1 новичок', 'название', 'би', '3']
# ['фаза вода', 'лучевой тв', 'метр', '1']
# ['выдающийся художник']
# ['курьер почему', 'секретарь', 'неужели', 'кафе', 'грязно', 'видеть', 'ван', 'n']
# ['д объективно', 'европа возможный', 'европа', 'би']
# ['никакой дело', 'грунт сад', 'гражданский война', 'непогода', 'артамонов']
# ['комфорка т', 'китай 1', '9 миллион', '7 миллион', '6 миллион', '5 миллион', '4 миллион', '3 73', '8 33', '8', 'н']
# ['конференция буэнос', 'дель', 'r', 'o', 'a']
# ['берлин актёр']
# ['5']
# ['музей']
# []
# ['хазар']
# []
# ['таки банковый', 'оказаться следствие', 'обнародовать час', 'видимому невозможно', 'ликвидация', 'би']
# ['16 тель']
# ['весь су', '57 су', '22 су', '22', 'эз', 'вдобавок', 'f']
# []
# ['адвокат дочке', 'режиссёр']
# ['первых быстро', 'редакция']
# ['часть достигать', 'французски либо', 'русски культ', 'расследование фрейд', 'редко']
# ['человек естественно', 'русский знать', 'плохой отец', 'обращаться интересно', 'проблема', 'мама', 'говорить']
# ['суровый требовательность', 'коллизия напоминать', 'сенкевич', 'путём', 'основоположник']
# ['телеканал всё', 'напросто ворваться', 'дело']
# []
# []
# ['петербург']
# ['03']
# ['страна']
# []
# ['круг']
# ['нитка состоять', 'нитка', 'власть', '50', '5']
# ['заключить делать', 'оно']
# []
# []
# ['расчёт іаі', 'первичный 33', 'бумажный комбинат', '9 миллион', '4 миллион', '5']
# ['donoghues']
# ['дело декларация', 'забывать']
# ['представитель оаэ', 'ишь']
# ['страна']
# ['дом chrisite', 'нью']
# ['высказываться пожелание', 'участвовать', 'агитировать']
# ['метр 2', '2']
# []
# []
# ['нужда', '70', '03']
# ['образ эколого']
# []
# []
# ['чёрный рецензия', 'очередь причина', 'научному изучать', 'вплотную подойти', 'б александр', 'аким г']
# ['учительница девонька', 'согласиться отдать', 'таки']
# ['ситуация усугубиться']
# ['очередь подвергнуться', 'лидер', 'женщина']
# ['содер это', 'получиться']
# ['анталья']
# ['семнадцать гран', 'мексика набрать', 'формулы', 'пилот', 'паулу']
# ['причина возможно', 'государствообразующий отрасль', 'юго', 'скоростной', '1880']
# ['ценный порода', 'закон закон', '5 тысяча', '3 миллиард']
# []
# ['машина почему', '2 новое', '154 ил', 'ток', 'зачастую', '154б', '124']
# ['реаниматология 5', 'метр']
# []
# ['премьер']
# ['следовать', 'поп', 'де', 'бездна']
# ['никакой дело', 'грунт сад', 'гражданский война', 'непогода', 'артамонов']
# ['суп жидкий', 'жемчуг мелкий', 'метр', 'вице']
# []
# ['экономический развитие', 'стремиться выработка', 'страна 20', 'формировать', 'пресс', 'прежнему']
# []
# []
# ['производиться россия', '54 12', 'производить']
# ['человек естественно', 'русский знать', 'плохой отец', 'обращаться интересно', 'проблема', 'мама', 'говорить']
# ['мясо жарить', 'гитлер мама', 'вещий вместе', 'откуда', 'крыса']
# ['советский существование', 'помнить']
# ['американский отношение']
# ['ха 30', 'район действие', 'период 2025', 'возможность', '8']
# ['перевозка 182', 'ть']
# ['российский гражданство']
# ['слиток 3', '7', '6', '5', '2', '13']
# ['3']
# ['коммунист всё', '8 44', '59 34']
# []
# ['шикотанский']
# []
# []
# ['образ 73', 'который идти', 'эква составить', 'эква']
# ['общество схожий']
# []
# ['платформа социально', 'лаборатория столько', 'консервативный государственно', 'депутат']
# ['стоматологический университет', 'персонал']
# ['человек сразу', 'видимому занять']
# []
# []
# ['90 т', '30 смерч']
# ['промышленный комплекс', 'метр 2', '1 2019', '7']
# ['основный причина', 'среднее 3', '3', '2']
# ['это', 'бизнес']
# []
# []
# []
# ['посоветовать совет', 'иртышский обь', 'енисейский обь', '5 миллион', '4 миллион', 'ч', 'майн', 'канско']
# []
# []
# ['аллергический хронический']
# ['энд формулы', 'серьёзный черепно', 'серия формула', '1 vip', '1', 'пресс']
# ['причина возможно', 'государствообразующий отрасль', 'юго', 'скоростной', '1880']
# ['третьих любо', 'соавтор 2014', 'вторых согреваться', 'это', 'нора']
# ['экология 13', 'сад каменск', 'ть', 'социально', 'очевидный', 'итог', '09']
# ['прокси', 'американо']
# ['удмуртский диалог', 'бумажный странный', 'серг протекать', 'серг', 'сделать', 'метафора', 'доброта', 'ар']
# ['спектакль менее', 'съёмка', 'серия']
# ['сакрализовать многовекторность', 'страна', 'сторона']
# ['лейк']
# ['тип', '6', '2']
# []
# ['провести']
# ['6 2016']
# []
# []
# ['очередь именно', 'голландия проявиться', 'всерьёз договориться', 'обмениваться', '06']
# []
# ['ти предмет', 'е место', 'оказаться санкт', 'санкт']
# ['паулу аба', 'объявить роспуск', '1 болельщик', 'модель формулы', 'команда формулы', 'формулы', 'ситуация', '350']
# []
# ['вавилов 110']
# ['этаж терминал', 'прервать 07', '30 понедельник', 'итар', 'заход', 'данные', 'борт', '800', '775', '737', '17']
# []
# ['лондон', 'би']
# []
# ['стимулировать рост', 'платить гражданин', 'перестройка нужный', '21 22', 'считать', 'ржавый']
# ['мнение покойный', 'слово']
# ['таки присоединиться', 'проголосовать']
# ['эз']
# ['8 24', '6 42', '0 30', '2 2015', '2', 'н']
# ['прежнему выставить']
# ['тарквини н', 'себастьен лёб', 'мичелиса хонда', 'е 8', 'е 16', 'ряд', 'м', 'лопес', 'катсбург', '10']
# []
# ['нур занять', 'эш', 'сися', 'мусульманин', 'азхар']
# ['стремление связать', 'поэзия сделать', 'обычный чтение', 'таки']
# ['потока', 'невозможность', '2']
# ['сися избранный', 'го']
# ['необходимый установить', 'оглы']
# ['пол грудинин']
# ['nizza несмотря']
# ['документальный научно']
# ['ть гран', 'е время', '1']
# ['завысить послабить']
# ['сосредоточиваться человек', 'читать', 'близкий']
# []
# ['январь']
# []
# ['химия создать', 'слово который', 'известный ранее', '2 новичок', '1 новичок', 'название', 'би', '3']
# ['пора топ']
# ['цепь связанный', 'французски всякий', 'переводчик кормильцев', 'издатель кормильцев', 'называться non', 'non']
# ['штраф пилот', 'гонка']
# ['эмигрант']
# []
# ['характеристика устанавливаться']
# ['мировой война', 'рояль', 'маше']
# ['бишкек']
# ['рубеж вместе']
# ['штраф', 'лейн']
# ['дом chrisite', 'нью']
# ['играть роль', '8м 1970', 'таки', 'вице']
# ['решать делать', 'образ посредством', 'доллар 1', '5 кг', '5', 'со2', 'вещий', '7']
# ['грузинский отношение']
# []
# ['2 поступать']
# ['чу урус']
# []
# ['издание книга', 'главный']
# ['день']
# ['йорк ряд', 'pgu', 'mos']
# ['юдо', 'человек']
# ['полуостров доставить']
# ['вроде 0']
# ['sos ряд']
# ['страна устранить']
# ['раид ар']
# ['тур']
# ['начаться', '5']
# ['го']
# ['причина возможно', 'государствообразующий отрасль', 'юго', 'скоростной', '1880']
# ['дина аза', 'отсутствие', 'аль']
# ['коронеля постичь', 'коронель пойти', '3 май']
# ['д it']
# ['лукум петренкобаев', 'мешать']
# ['01 strsljen', 'посадка x', 'посадка', 'x', '01', 'х']
# ['ха 2000', 'промышленный революция', 'год полигон', 'cae', '0']
# ['перехватчик миг', '31 воздушно']
# ['подобный фильм', 'д квота', 'придумывать', 'награда', 'любовь']
# ['клуб джентльмен', 'клуб гольф', 'гольф']
# ['месяц кстати', 'воздушный военно', 'американский год', 'британский']
# ['прежнему мыслиться', 'говорить выбирать', 'время стать', 'вариант табаков', 'губа']
# []
# ['18', '03']
# []
# ['зародыш']
# ['защита экс']
# []
# ['таки', 'содержание']
# ['провалиться пресс', 'разведчица', 'жена', 'ждать', 'абель']
# ['стоить особняком', 'расстройство', 'время']
# ['ха год', 'постметафизический философия', 'направление', 'маяковский']
# ['2014 сочи']
# ['0']
# []
# ['y sky', 'l mam', '50 tl', '300m yj', 'разведывательно', 'variant', 'su', '9', '7', '1']
# []
# ['синить наташа', 'простой дуга', 'невыносимый оба', 'женщина видеть', 'довести сумасшествие', 'встречаться значит', 'сторона', 'серафим', 'связывать', 'ручка', 'просто', 'неделя', 'доступ', 'делать', 'давать']
# []
# ['член созвать', 'законный требование', 'шаг', 'допуск']
# ['фадлить аль', 'нуср ахрараш', 'каида аль', 'гамаа аль', 'ль']
# []
# []
# ['электронный тв', 'средство управление', 'сенсор', 'партия', 'оптический', '11b']
# []
# []
# ['пустяк увидеть', 'двадцать год', 'восток туда', 'рим']
# []
# []
# []
# ['зал риа', 'д прошедшее']
# ['проиграть выборы', 'повестка']
# ['возможный допинг', 'допинг', 'контроль']
# []
# ['давать возможность', 'ряд']
# ['2020 год', 'платить']
# []
# []
# []
# []
# ['рукбан эт']
# ['03 вопрос', '03']
# ['р 29', 'петербургский научно', '17', '07', '03']
# ['место похоже', 'велосипед ролик']
# []
# ['л ростропович']
# ['ха 1970', 'ломоносов приводить', 'видимому ограниченный', 'абсолютный размер', 'цитата', 'социально']
# ['40 хватить', '15 6', 'ча', 'слово', 'отметиться', '8']
# ['демократ род', 'духе']
# []
# []
# ['фронтовик рассказ', 'ингушский население', 'ингушетия таковой', 'ингушетия кабардино', 'д т']
# ['секретарь нести', 'политик система']
# ['го 2']
# ['реактор ввэр', '5 тысяча', 'own', '1200']
# []
# ['обращать внимание', 'фонд хедж', 'фонд']
# []
# ['мечеть баден', 'турецко']
# ['предчувствие']
# []
# ['который сводиться']
# []
# []
# []
# ['вертолёт ми', '26']
# ['километр']
# ['присоединиться']
# []
# []
# ['вюртемберг шлезвиг']
# ['носитель союз', '2511 космос', 'эз', '2']
# []
# []
# []
# []
# []
# ['период 2016', 'останавливаться']
# ['сторона']
# ['пора партия', 'инициатива']
# ['фосфор 2', '3 миллион', '0 2', 'аграрно']
# ['проект театра', 'бланш', 'ап']
# ['усилиться дождь', 'сша формулы', '00 мск', 'стартовать']
# ['е итог', 'машина']
# ['сегмент 12']
# []
# ['строительство 84', 'автомобилестроение 208', '5 тысяча', '4 тысяча', '3 тысяча', '7 тысяча', '7']
# ['сезон август', 'мучить мажором', '3 анна', 'детективъ']
# []
# ['год пояснять', '2 п', '15 п']
# ['современный площадка', 'десятилетие привести']
# ['пушка царь', 'модельер гений', 'колокол ту', 'э', 'хотеться', 'п', 'музыка', 'жуковский', 'е', 'делла', 'бауман']
# ['энд сузук', 'стукнуть оба', 'стоп 13', 'пришествие сйфти', 'уик', 'сложность', 'пит']
# ['заходить клиент', 'грабёж']
# ['препятствие социально', 'четыре']
# ['процесс материально']
# ['го 11', 'взять целиком', 'этап', 'подиум']
# []
# ['обряд']
# []
# ['начаться', '5']
# []
# []
# ['решение несколько', 'полковник н', 'обычно делать', 'беседа главное', '3 дунай', 'творец', 'сумма', 'согласовывать', 'пустячный', 'дефект', '23']
# ['укрэнерго']
# ['таки']
# ['член ку', 'ха год', 'клукс']
# ['уголь']
# ['история множество', 'го 78', 'юстиция', 'представлять', 'понимать', 'лохотронщик']
# ['выявить ход']
# ['единоросс']
# ['сатирико']
# ['топовый youtube', 'случайно поклонник', 'свобода слишком']
# ['платформа социально', 'лаборатория столько', 'консервативный государственно', 'депутат']
# []
# []
# []
# ['сцена переходить', 'бандит далее', 'полчаса', 'гриейя']
# ['ветка']
# []
# []
# ['ть позиция', 'лейн наряду', 'bamboo lukoil']
# []
# ['метод принимать', 'вице']
# []
# ['уверить']
# []
# ['набор сцена', 'любовь хэви', 'автор', '68']
# ['дина аза', 'отсутствие', 'аль']
# ['сектор развитие']
# ['феномен естественно']
# ['последний месяц', 'поддержка помочь', 'справиться', 'монако', '2014']
# ['сокровенный бисом', 'принадлежать 100', 'ангельски радоваться']
# ['около']
# ['социальный ответственность', 'метр появиться', 'эндаумент']
# ['преобразование', 'вице']
# ['американский отношение']
# ['полоса превратиться', 'образ покинуть', 'стометровка стоять', 'стометровка преодолевать', 'охранник бежать', 'стометровка', 'бежать', 'пропуск', 'право', 'помиловать', 'ага']
# ['место 13', '00 17']
# ['который сло']
# []
# ['реактор контрольно', 'изменить']
# ['мститель противостояние']
# ['заявка претендент']
# ['подтверждение состав', 'говорить указывать', 'фигурант', 'римско', 'бумага']
# ['караваев']
# ['серьёзный преступление', 'развернуться сша', 'план окончание', 'симпатия']
# ['результат 1', 'экология', 'пришелец']
# ['товарищ', '253']
# ['суп жидкий', 'жемчуг мелкий', 'метр', 'вице']
# []
# ['п']
# ['юг крокодил', 'прачечный отделение', 'леди 5', 'ка банно', 'подполковник подумать', 'подполковник', 'дружески']
# []
# ['оперировать факт', 'р 12', '12', 'разному', 'многий']
# ['петербург 1836', 'петербург', 'топ']
# []
# ['стремление связать', 'поэзия сделать', 'обычный чтение', 'таки']
# []
# ['ресурс богатство', '8']
# ['текущий сезон', 'семь гран', 'работать устраивать', 'энд', 'формулы']
# ['1']
# ['число эмигрант', 'метр рио', 'поэт', 'де']
# []
# []
# ['город рф']
# ['запад джаузджан']
# []
# []
# ['отдельный издательство']
# ['отход жилищно', '5 триллион', '30 триллион', '12 миллион', 'экология', 'констатация', '95', '0']
# ['человек естественно', 'русский знать', 'плохой отец', 'обращаться интересно', 'проблема', 'мама', 'говорить']
# ['курс кпрф', 'партия', '2017']
# ['случай 100']
# ['преступление', 'п', 'действие']
# ['6 2016']
# ['двигать решить', 'услышать']
# ['психология', 'вторых', 'вестись']
# ['2005 российско', '2005 каспий', 'антитеррор']
# ['п состоять', 'вообще воплощение', 'эсер', 'художники', 'думать', 'время']
# []
# ['социальный ответственность', 'метр появиться', 'эндаумент']
# ['интерпретация минска', 'год пресс', 'step сурков', 'by']
# ['агитация вообще', '09']
# []
# ['номинант']
# ['р проза', 'никуда свалиться', 'el 12', '17 2017', 'традиционалист', 'современник', 'пить', '01']
# ['страна стремиться', 'анализироваться глава', 'д', '94282', '91187', '89332', '802', '6518', '5', '306', '294', '227', '07787']
# []
# ['метр вест', '91865', '906980', '88788', '505', '5', '47', '238', '235', '04054', '025']
# []
# ['человек человек', 'новое это', 'дух высказаться']
# []
# ['д расчёт', 'курс', '12', '11']
# ['йорк 120']
# []
# ['чудесный жар', 'ухо стоялый', 'узнать добавить', 'слово плохой', 'сердце голов', 'анекдот рассказывать', 'снег', 'рассказ', 'поэму', 'повесть', 'крыльцо']
# []
# ['светлый дата', '023 премьер', 'мешать']
# []
# ['пользоваться спрос', 'оргкомитет сочи', 'образ заёмщик']
# ['00']
# ['неудачно срежиссировать', 'занавеска состряпать', 'деньга повесить', 'садиться', 'образ', 'кошка']
# ['экология 13', 'сад каменск', 'ть', 'социально', 'очевидный', 'итог', '09']
# []
# []
# ['предчувствие']
# []
# ['посвятить женщина', 'очередной 68']
# ['штурмовой 1', 'часть 1', 'разведчик u', 'причём огонь', 'механизировать 101', 'вертолётный корабль', 'американский транспортник', '8b s', '8 1', '3 е', '3 3', '2 е', '16 60', '15e f', '14a s', '14a f', '10a av', '1 18', '1 12', 'ть воздушно', '52 11', '18c a', 'воздушно', 'a', '11', 'пора', 'невидимка', 'мн']
# []
# ['марко русско', 'который плодовитый', 'история начинаться', 'метр', 'дно']
# []
# []
# ['пазуха']
# []
# []
# ['вице']
# ['половина 1960', 'морской сила', 'kl', '47']
# ['мир именно', 'это', 'человек']
# ['конкретный узник', 'узнать', '5']
# ['рождение одетта', 'преимущество балерина', 'одиллия главный', 'французско', 'спектакль', 'либо', 'говорить']
# []
# []
# []
# ['906980', '901511', '89332', '7187', '5', '39', '296', '227', '14', '07554', '0551']
# []
# ['таки читать']
# ['метр круг', 'время отстоять', 'сезон']
# ['ха год', 'постметафизический философия', 'направление', 'маяковский']
# ['советский союз', 'место 23', 'связь', 'сверстник', '1']
# ['вторых разница', 'четыре']
# ['ха 1970', 'начало 1990', 'демократ привести', 'встреча премьер', 'германий']
# ['назвать премьер', 'год 100']
# ['пустяк увидеть', 'двадцать год', 'восток туда', 'рим']
# []
# ['текст который', 'коллега замечание']
# []
# []
# ['би']
# ['неделя формулу', 'казалось формула', '1 услышать']
# []
# ['метр обер', 'материальный выгода']
# ['аморт любовь', 'многий', 'живой']
# []
# ['муниципалитет']
# ['либо военно']
# ['шептать смотреть', 'словопрение подбегать', 'любимый стих', 'кладовая хотеть', 'рак', 'поэт', 'переулок', 'год']
# ['участник возглавлять']
# ['вице']
# []
# []
# ['завысить послабить']
# ['му 6', 'й 6', 'американский военно']
# ['выдумка']
# []
# []
# []
# ['поступить премьер', 'вторых']
# []
# ['партийный характеристика', 'друг']
# []
# ['2 1']
# ['эрик вернь', 'неделя формула', 'топ', 'стопа']
# ['присоединиться санта', 'буденовец лошадка', 'хо', 'стекло']
# ['конкретно являться']
# ['правило', 'оставаться']
# []
# ['нога', 'день']
# ['конашенков']
# ['процесс внутри', 'заключить договорённость', 'хау']
# ['решать', 'нефть']
# ['билдинг нью', 'стейт']
# ['даун именно', 'шпион']
# ['п мужчин', '9 п', '6 56', '6 43', '5 п', '4 30', '2 21', '8', '1']
# ['обязательно повезти', 'стихотворение']
# ['2 тревожить']
# []
# []
# ['мм осколочно', 'электронную', 'камикадзе', 'видимому', 'in', '5', '40']
# ['03']
# ['статья предлагать', 'дорожно']
# ['меньшинство']
# ['строитель сдавать', 'половина 1970', 'начать строить', 'вертолётный корабль', 'м', '02']
# []
# ['вечер посвятить']
# ['ректор санкт']
# ['обозримый будущее', 'бнуть', '11', '10', '09', '08', '04', '02']
# ['говорят']
# []
# ['8 24', '6 42', '0 30', '2 2015', '2', 'н']
# ['канада явно', 'тренер', 'сборный', '12']
# ['де']
# ['д']
# ['frontal cortex', 'белок']
# []
# ['нитка 27', 'метр', '8']
# ['1 участник', 'формулы', 'сан', 'россия', 'машина', 'гран']
# ['стремление связать', 'поэзия сделать', 'обычный чтение', 'таки']
# ['хе хе', 'масло саркастически', 'заехать н', 'знать са', 'знать', 'хотеть']
# []
# ['murid', 'livejournal']
# ['безоблачный перспектива']
# ['трасса стать', 'подиум сразу', 'команда возможно', 'веха история', 'формулы', 'гран']
# ['позиция старт', 'гонка оставить']
# ['туркменистан являться', 'китайский туркмено', 'источник энергия', 'западный юго', '21 миллиард', '2 миллиард', 'связанный', 'брать', '18']
# []
# ['свободный справедливый']
# ['российский конфликт']
# ['соотношение использовать', '07']
# []
# []
# ['свой сто', 'йорк плюс', 'сидеть', 'преступление', 'нью', 'муж']
# ['селанна 18', '1']
# ['ломаться']
# ['эс', 'би']
# ['равно']
# []
# ['претендент']
# ['привычный поднимать', 'условие']
# ['поменяться координатор', 'давление власть', 'сити', 'вести']
# ['очередь именно', 'голландия проявиться', 'всерьёз договориться', 'обмениваться', '06']
# ['объект 17', 'станиславский', 'немир']
# ['формула который', 'управляться мир', 'сайт gefter', 'немногий описание', 'гражданский ценность', 'таки', 'кандидат']
# ['метр']
# []
# ['обращение опубликовать']
# []
# ['участник картель']
# []
# ['программа который', 'предоставить человек']
# []
# ['хау', 'сторона', 'обидный']
# []
# ['решать делать', 'образ посредством', 'доллар 1', '5 кг', '5', 'со2', 'вещий', '7']
# ['чудесный жар', 'ухо стоялый', 'узнать добавить', 'слово плохой', 'сердце голов', 'анекдот рассказывать', 'снег', 'рассказ', 'поэму', 'повесть', 'крыльцо']
# ['страна']
# ['психологический отношение', 'модель управление', 'слово', 'пересилить', 'очередь', 'оставаться', 'манящий']
# 0                                                                                                                                                                                                                                                                                          []
# 1                                                                                                                                                                                                                                                                                [вр новатэк]
# 2                                                                                                                                                                                                [хороший довольный, семья говорящий, русски плохо, огорчительный факт, россия, писать, метр]
# 3                                                                                                                                                                                                                                                                                          []
# 4                                                                                                                                                                                                                                                                          [гигант спортивно]
# 5                                                                                                                                                                                                                       [феттель вместе, перес результат, авария спровоцировать, пит, лейный]
# 6      [ть 82, российский торгово, е место, го 98, го 96, го 92, го 9, го 86, го 83, го 8, го 78, го 77, го 76, го 74, го 72, го 71, го 68, го 66, го 63, го 62, го 61, го 60, го 58, го 56, го 53, го 48, го 46, го 45, го 43, го 42, го 41, го 40, го 38, го 3, го 29, го 20, го 15, го 11]
# 7                                                                                                                                                                                                                                                                             [д разработать]
# 8                                                                                                                                                                                                           [центр russia, издание www, зенитный комплекс, российско, план, намерение, heise]
# 9                                                                                                                                                                                                                                                                                          []
# 10                                                                                                                                                                                                        [половинка термо, неподцензурный город, банка бросить, таблетка, старший, садиться]
# 11                                                                                                                                                                                                                                                                             [метр 2020, 6]
# 12                                                                                                                                                                                                                                                                                         []
# 13                                                                                                                                                                                                                                 [сахалинск москва, план жюри, вынужденный общаться, е, 40]
# 14                                                                                                                                                                                                                                                                                   [авторы]
# 15                                                                                                                                                                                                                                                                                         []
# 16                                                                                                                                                                                                                                                                                         []
# 17                                                                                                                                                                                           [половина 2016, поколение 85, кобальт четыре, 6 миллион, 3 миллион, 1 миллион, 1, литий, го, би]
# 18                                                                                                                                                                                                                                                                             [ть, победный]
# 19                                                                                                                                                                                                                                                                                         []
# 20                                                                                                                                                                                                                                                                                         []
# 21                                                                                                                                                                                                                                                                [осуществлять контроль, эз]
# 22                                                                                                                                                                                                                                  [ленин 26, двоить семьдесят, стоять, мини, месторождение]
# 23                                                                                                                                                                                                                                                                                       [00]
# 24                                                                                                                                                                                                                                                                                         []
# 25                                                                                                                                                                                                                                                                                         []
# 26                                                                                                                                                                                                                                                   [промышленный геотермально, страна, hdr]
# 27                                                                                                                                                                                                                                                                                         []
# 28                                                                                                                                                                                                           [член g, полоса рейган, надежда ждать, военный интервенция, айлёнда впереди, эн]
# 29                                                                                                                                                                              [третей меж, радоваться наблюдать, авто конёк, диагноз сальери, сальери, свободный, просто, несправедливость]
#                                                                                                                                                 ...
# 969                                                                                                                                                                                                                                                                     [российский конфликт]
# 970                                                                                                                                                                                                                                                            [соотношение использовать, 07]
# 971                                                                                                                                                                                                                                                                                        []
# 972                                                                                                                                                                                                                                                                                        []
# 973                                                                                                                                                                                                                                     [свой сто, йорк плюс, сидеть, преступление, нью, муж]
# 974                                                                                                                                                                                                                                                                           [селанна 18, 1]
# 975                                                                                                                                                                                                                                                                                [ломаться]
# 976                                                                                                                                                                                                                                                                                  [эс, би]
# 977                                                                                                                                                                                                                                                                                   [равно]
# 978                                                                                                                                                                                                                                                                                        []
# 979                                                                                                                                                                                                                                                                              [претендент]
# 980                                                                                                                                                                                                                                                            [привычный поднимать, условие]
# 981                                                                                                                                                                                                                                    [поменяться координатор, давление власть, сити, вести]
# 982                                                                                                                                                                                                            [очередь именно, голландия проявиться, всерьёз договориться, обмениваться, 06]
# 983                                                                                                                                                                                                                                                         [объект 17, станиславский, немир]
# 984                                                                                                                                                                                  [формула который, управляться мир, сайт gefter, немногий описание, гражданский ценность, таки, кандидат]
# 985                                                                                                                                                                                                                                                                                    [метр]
# 986                                                                                                                                                                                                                                                                                        []
# 987                                                                                                                                                                                                                                                                  [обращение опубликовать]
# 988                                                                                                                                                                                                                                                                                        []
# 989                                                                                                                                                                                                                                                                        [участник картель]
# 990                                                                                                                                                                                                                                                                                        []
# 991                                                                                                                                                                                                                                                 [программа который, предоставить человек]
# 992                                                                                                                                                                                                                                                                                        []
# 993                                                                                                                                                                                                                                                                   [хау, сторона, обидный]
# 994                                                                                                                                                                                                                                                                                        []
# 995                                                                                                                                                                                                                      [решать делать, образ посредством, доллар 1, 5 кг, 5, со2, вещий, 7]
# 996                                                                                                                                                    [чудесный жар, ухо стоялый, узнать добавить, слово плохой, сердце голов, анекдот рассказывать, снег, рассказ, поэму, повесть, крыльцо]
# 997                                                                                                                                                                                                                                                                                  [страна]
# 998                                                                                                                                                                                           [психологический отношение, модель управление, слово, пересилить, очередь, оставаться, манящий]
# Name: content_norm_text, Length: 999, dtype: object

# %% [markdown]
# Результат бредовый

# %% [markdown]
# **Результат 3: неудачно**
# По ненормализованным данным получаем кучу непонятных словосочетаний, среди которых встречается что-то толковое, но в целом ***неудовлетворительно***.

# %%
data['content'].apply(procRake)
# Out:
# ['функцию организатора', 'федеральном уровне', 'учебных заведений', 'убийства закрыто', 'тех регионов', 'такую ответственность', 'судебный процесс', 'стороны силовиков', 'стараемся координировать', 'становимся кандидатами', 'сих пор', 'российской экономике', 'различных сми', 'проходят лекции', 'провести акцию', 'предлагать взять', 'права женщин', 'поступали угрозы', 'поставленными задачами', 'пассивное наблюдение', 'открытость политики', 'освобождение политзаключенных', 'огромное влияние', 'обсуждения социально', 'образом действовать', 'неподдельная заинтересованность', 'необходимо каким', 'некоторые пытаются', 'некоторое время', 'нашу форму', 'наступления консерватизма', 'наемные работники', 'московских активистах', 'московские активисты', 'многие интересуются', 'многие боятся', 'мнению одного', 'либеральной альтернативы', 'контрактную армию', 'команде единомышленников', 'избегая насилия', 'идеологически силе', 'заканчивая школу', 'единого руководства', 'должен присоединиться', 'деятельности партии', 'день борьбы', 'готовы взять', 'городской повестке', 'выполнить взятые', 'возможные усилия', 'военного бюджета', 'ведущих специалистов', 'ведем борьбу', 'антикоррупционные акции', 'административному правонарушению', '8 марта', '10 регионах', 'нам приходится', 'нам вступить', 'это говорит', 'политическую деятельность', 'общепартийных мероприятиях', 'который публикуется', 'власти политикой', 'нам', 'это', 'мероприятиях', 'который', 'деятельность', 'власти', 'числе', 'честность', 'черносотенцы', 'факту', 'участию', 'участвуем', 'украине', 'убит', 'тимур', 'также', 'считаем', 'стране', 'стороне', 'справляются', 'справедливость', 'содержался', 'ситуации', 'сизо', 'сегодня', 'свободукириллубобро', 'россии', 'решила', 'решил', 'репрессии', 'ребята', 'расскажу', 'рамках', 'пропаганду', 'проблемы', 'пришел', 'присутствовал', 'преподаватель', 'прекратят', 'похищен', 'последовательность', 'поняла', 'понимать', 'получается', 'пока', 'поддержки', 'переход', 'переехал', 'отправились', 'оставаться', 'освобождения', 'оказал', 'обязательства', 'обязанность', 'обществознанию', 'несмотря', 'недавно', 'находится', 'наркотики', 'напомнить', 'надеюсь', 'москву', 'могут', 'мартова', 'лозунгом', 'крыма', 'которой', 'колонией', 'кинопоказы', 'карелию', 'искренность', 'исключением', 'затем', 'занимали', 'задержаны', 'завершился', 'жизни', 'ельцина', 'добиться', 'грозит', 'выборах', 'вся', 'вступление', 'войны', 'возможных', 'власть', 'виктора', 'виктор', 'бывает', 'близкой', 'активистов', 'адрес', '17']
# ['штокмановское месторождение', 'холдинг разорвет', 'тарифам расценкам', 'также забывать', 'считают аналитики', 'считать окончательными', 'стратегию правительства', 'страны снг', 'старается прибрать', 'сообщил вчера', 'словам минликаева', 'словам ананенкова', 'сказать сложно', 'свои усилия', 'свободном рынке', 'решать который', 'расчетам холдинга', 'расчетам аналитиков', 'прогнозам монополиста', 'отмечают аналитики', 'остается надеяться', 'одной стороны', 'независимым производителям', 'независимые производители', 'нашим расчетам', 'налицо отход', 'мнению холдинга', 'которое рассчитывает', 'иными словами', 'заключенные контракты', 'другие страны', 'другие производители', 'долгосрочных контрактах', 'добычу газа', 'добыче газа', 'дефицита газа', 'газового конденсата', 'внутренние производители', 'внутреннее потребление', 'банкротства предприятий', 'банальной экономии', '880 млрд', '316 млрд', '3 %.', '2020 
иями', 'правительствами россии', 'интересами россии', 'интересам россии', 'южную европу', 'трансбалканский газопровод', 'соединяющих европу', 'поскольку турции', 'относительно турции', 'имеющийся газопровод', 'европу ».', 'гипотетический газопровод', 'турцию ракетно', 'минуя турцию', 'турцией зиждется', 'турецкие проекты', 'ситуация изменилась', 'сирию ».', 'сжиженном газе', 'связать катар', 'принципе это', 'которым пока', 'которому газ', 'касается катара', 'иорданию ).', 'другие российско', 'данном случае', '2017 год', 'территорию турции', 'ратификации соглашения', 'сирии', 'россии', 'турции', 'европу', 'газопровод', 'турцию', 'это', 'турцией', 'территорию', 'соглашения', 'случае', 'ситуация', 'сирию', 'российско', 'ратификации', 'проекты', 'пока', 'катара', 'катар', 'иорданию', 'год', 'газе', 'газ', 'южными', 'экспорта', 'экспорт', 'экономических', 'числе', 'центра', 'хотя', 'хамас', 'франция', 'уходить', 'утверждение', 'утверждалось', 'украину', 'указывает', 'удовлетворять', 'турция', 'туркмении', 'туркменией', 'трудности', 'транспортировки', 'тому', 'сша', 'счетов', 'существуют', 'стороны', 'статью', 'статье', 'состоялся', 'соседи', 'соединяться', 'согласятся', 'совместно', 'см', 'северо', 'связано', 'связанным', 'свидетельствовать', 'саудовцы', 'сада', 'россия', 'россией', 'речь', 'регионе', 'реализована', 'реализация', 'работавший', 'процесс', 'проходить', 'пространства', 'прежде', 'представление', 'предпочел', 'предполагалось', 'правда', 'поэтому', 'построили', 'поставках', 'понятно', 'политические', 'пойти', 'первый', 'отметить', 'открытие', 'отве ...
# ['калужской области', 'возглавляемой эмиссаром', 'данным цос', 'цос', 'фсб', 'сообщили', 'сообщении', 'рф', 'прибыл']
# ['як гвоздю', 'щелку лежащую', 'шести трубках', 'шатают дом', 'шалманщика синтпайком', 'черных перьев', 'чашку кальяна', 'це гарно', 'хочешь услышать', 'хотел продолжения', 'холодной воды', 'удивлением уставился', 'тьме свет', 'тщательно потряс', 'требующие преодоления', 'требует времени', 'тоскливо разом', 'тепло сделалось', 'татуировки гильдии', 'тайных мест', 'стылом море', 'страшилки всякие', 'страхов реальных', 'страх забирал', 'сторожа миражей', 'столько приготовил', 'столом рядом', 'стены трутся', 'старых друзей', 'старым парком', 'споро извлекал', 'собрал ножом', 'снова передал', 'смертной тоски', 'слушал старика', 'слушал отца', 'скрежетаньем скрижали', 'сеты такие', 'сдвижной крышкой', 'свой сон', 'свой азилий', 'своей волне', 'самом деле', 'садись играть', 'ругался вполголоса', 'решил никому', 'раскрыл ладонь', 'разных пузырьков', 'разношерстных вагонов', 'размял руки', 'размахивая руками', 'протер глаза', 'просто время', 'пропилил стену', 'промозглом склепе', 'продолжая читать', 'помедлили малость', 'получили отдохновение', 'полетели искры', 'покинул ариэль', 'пойдем поищем', 'подхватил ворот', 'поднялись выше', 'подлинности знаков', 'подействовало пока', 'повеяло теплом', 'поверхностью планеты', 'перемешивая содержимое', 'первых рядах', 'очередной колбы', 'оттенками меда', 'отозвался рифмоплет', 'открывшийся портал', 'откроет правду', 'отечественная подделка', 'отер пот', 'отверстию люка', 'огонь выплеснулся', 'обрел опору', 'обратный путь', 'новые трудности', 'нового завтра', 'несертифицированный перевод', 'непростая смесь', 'ненавидел отца', 'невероятно длинный', 'неверном свете', 'небесах пошли', 'начале композиции', 'наступила тьма', 'настелил пол', 'нарушил нашу', 'нанести немного', 'молодой человек', 'мнимых страхов', 'мнимые жахи', 'минуту неподвижно', 'милости прошу', 'мамой договоренность', 'мамкой погутарили', 'маленькую колбу', 'лицо казака', 'легко оттолкнувшись', 'крыльцо выйдет', 'краям цистерне', 'костяным мундштуком', 'композиция закончилась', 'качал головой', 'кармана термотаблетку', 'кальян полетела', 'какие нахлынули', 'каждом оппонентов', 'иные лежали', 'интересом наблюдал', 'индивидуально заняться', 'избавит фальши', 'знает сайра', 'засохших плодов', 'заранее сказать', 'заинтересовал именно', 'живые люди', 'живой чи', 'жестяных жуков', 'жесткой меже', 'ждать долго', 'жале ужей', 'еловой хвои', 'душа свернулась', 'душа замирала', 'другое дело', 'дразнили надоблачником', 'дородный мужчина', 'должен понять', 'долго копался', 'долго ворочался', 'довольно близкого', 'десять слов', 'действо продолжалось', 'дед повел', 'дальнего тамбура', 'дали сок', 'давних бесед', 'грузовые платформы', 'груз давил', 'граница правды', 'головной убор', 'голове состава', 'выше поднялся', 'вытянув вперед', 'выбирались наружу', 'временем развернул', 'временем кинул', 'ворота лжи', 'возможность послушать', 'внешней галерее', 'вижу отчетливо', 'видели окрестности', 'взяли спирта', 'взошла луна', 'взгляд холодный', 'веских причин', 'верхнюю губу', 'вверх хоботы', 'важное видел', 'вагоны чередовались', 'бурно обсуждали', 'будущее готовит', 'брать подольше', 'богато маю', 'белом колпаке', 'аппарат ожил', '10 минут', '... колдует', '– эх', '– ух', '– та', '– раздувай', '– понимаешь', '– подействовало', '– наркоту', '– лишь', '– дропер', '– должны', '– годится', '– врать', 'хотите –', 'ужас –', 'отказывался –', 'мгновение –', '... –', 'тихон слушал', 'тихон промолчал', 'тихон почувствовал', 'тихон заметил', '– тихон', 'это недешево', 'это наводило', '– это', '… понимаешь', 'старик шептать', 'старик ухмыльнулся', 'подкачал …', 'отправил туда', 'однако журибеда', 'муку …', 'затягивает туда', 'журибеда чихнул', 'журибеда закивал', 'добавил туда', 'стихомант насупился', 'словно крылья', 'словно вынырнул', 'дежнев поднялся', 'дежнев вспомнил', 'точно ярко', 'тихона заметили', 'стал участвовать', 'пришла тихону', 'оно вроде', 'одна термотаблетка', 'настолько уверен', 'мимо стойки', 'лица путешественников', 'кончилось время', 'кому ш ...
# ['– сказали', '– кроме', 'эксперты сомневаются', 'эксперт уточняет', 'цср ),', 'цель заложена', 'учета индивидуального', 'уровней 5', 'текущей ситуации', 'считает стерник', 'существенную роль', 'существенную разницу', 'строительные услуги', 'согласно стратегии', 'службе минстроя', 'рынке ».', 'реализующихся девелоперами', 'прогнозу минэкономразвития', 'прогноз сделал', 'потребностью населения', 'полтора раза', 'поддержке спроса', 'повестке дня', 'платежеспособным спросом', 'населения »', 'многоквартирного жилья', 'минстрой поясняет', 'макроэкономическом прогнозе', 'льготному
 'отделить аккумулятор', 'основной элемент', 'окружающую среду', 'обычный автомобиль', 'общественных гаражах', 'обмен занимает', 'нынешнем году', 'ночные часы', 'новым жильем', 'новой индустрии', 'неправильным утверждать', 'неожиданным образом', 'начале 2000', 'начала продажи', 'находит применение', 'налоговые преимущества', 'накопителях энергии', 'наиболее бедных', 'мэа ),', 'московской области', 'мировых поставок', 'мира бьются', 'минтранс наблюдают', 'меняете аккумулятор', 'меньшая потребность', 'машиностроительные корпорации', 'машина вызывается', 'любом случае', 'логистических погрузчиков', 'краснодарском краях', 'которым германия', 'компания поставила', 'компания подключает', 'компаний it', 'коммунальный транспорт', 'коммерциализируют продукты', 'кобальтом осложняется', 'клининговой техники', 'клиент покупает', 'китайское руководство', 'километровом заезде', 'исследователи сообщают', 'исследователи выясняли', 'исследовании сообщается', 'использование аккумуляторов', 'ионный аккумулятор', 'инфраструктурные компании', 'интерес поднебесной', 'изменить мир', 'изготовление аккумулятора', 'идти речь', 'здоровья человека', 'запас энергии', 'забот доедешь', 'жилых кварталах', 'едете туда', 'европейскому пути', 'другому пути', 'другие исследования', 'доля потребляемой', 'дизельным автомобилям', 'дизельное топливо', 'дизельного двигателя', 'действующих атомных', 'действует мотивация', 'данном случае', 'давайте подумаем', 'группе стран', 'городской электросети', 'головок цилиндра', 'глобальный авторынок', 'глобальном масштабе', 'выхлопной системы', 'высокие тарифы', 'выпускает батареи', 'выделенным полосам', 'выделенной полосе', 'втором месте', 'вопиющим упущением', 'вообще производящаяся', 'возобновляемые источники', 'включают свет', 'ведущие позиции', 'быстрозаряжаемой батареи', 'быстро извлекается', 'быстрая подзарядка', 'будущем электротранспорта', 'будущем затруднено', ...
# ['черная женщина', 'харви вайнштейна', 'фрэнсис макдорманд', 'трансгендерной женщине', 'таким образом', 'счастливы вместе', 'сразу вставать', 'спортивной драме', 'сперва убедиться', 'современные кинодеятели', 'сложности замысла', 'свой договор', 'своим призам', 'сведение звука', 'самых лучших', 'сама узнала', 'российском спорте', 'роджер дикинс', 'разнообразие разнообразием', 'равно достался', 'права женщин', 'последовательно шли', 'позитивных изменениях', 'победители упорно', 'перепутавшего конверты', 'первую любовь', 'первой победной', 'основном женщины', 'основании которого', 'одной статуэтки', 'одной номинанткой', 'некоторые заменили', 'настоящие речи', 'написавший саундтрек', 'мужчине –', 'монтаж фильма', 'монтаж звука', 'менее конъюнктурная', 'любил фильмы', 'лучшую песню', 'лучший фильм', 'лучший грим', 'истории организации', 'зале женщин', 'единственная номинированная', 'достойные претенденты', 'достойны любви', 'допинговых нарушениях', 'джимми киммел', 'дель торо', 'границе эббинга', 'глубоких ролей', 'главными героями', 'вспомнил ведущий', 'вновь ошиблись', 'билборда »,', 'активисты рассказали', 'актерского состава', '« спасибо', '« побег', '« бегущего', 'ровесник церемонии', 'это касается', 'сказать скучной', 'призвавший победителей', 'получивший приз', 'показательное кино', 'обошел заслуженный', 'году женщина', 'й церемонии', 'вручали награды', '«', 'церемонии', 'это', 'сказать', 'приз', 'победителей', 'обошел', 'награды', 'кино', 'й', 
# ['это указывает', 'это занятие', 'частные неудачи', 'целом обстановка', 'уходить далеко', 'указанных регионах', 'удастся хотя', 'третий вариант', 'террористическая организация', 'территорию ливана', 'таковыми являются', 'состоянии остановить', 'сирийской армии', 'сирийский кантон', 'своих границ', 'своим союзником', 'самое происходит', 'решать проблему', 'режиме блицкрига', 'расчеты оперативно', 'просто далека', 'произвол судьбы', 'провинциях идлиб', 'приграничных районах', 'последнее время', 'позитивном ключе', 'поддержке вашингтона', 'оперативную глубину', 'одного курда', 'общих границ', 'непосредственной близости', 'начинать сначала', 'начинает развиваться', 'настоящее время', 'москва ).', 'многим причинам', 'ливанской армией', 'либо вступить', 'курдскому вопросу', 'курдское ополчение', 'каких обстоятельствах', 'интересах коалиции', 'значительно активизировались', 'договоренностях анкары', 'дальше кунейтры', 'вполне возможно', 'восточной гуте', 'возымело эффекта', 'весьма возможно', 'афганскому сценарию', 'территории сирии', 'сирии ),', 'востоке страны', 'турецкая война', 'тому моменту', 'сирийском твд', 'россии ).', 'пользу москвы', 'востоке сирии', 'сирии', 'востоке', 'тому', 'твд', 'россии', 'москвы', 'война', 'ясно', 'юго', 'эз', 'штатам', 'частям', 'хасеке', 'хайфе', 'формально', 'умеренных', 'турции', 'террористами', 'также', 'сути', 'судя', 'союзников', 'состоящие', 'соглашение', 'смогла', 'смириться', 'сложившуюся', 'сказать', 'сирийско', 'силы', 'сдс', 'россию', 'регионе', 'рассчитывать', 'рассекать', 'районе', 'ради', 'признала', 'придется', 'прежде', 'предписано', 'поэтому', 'похоже', 'потери', 'побежденной', 'перспективное', 'переход', 'перекинется', 'ошибки', 'отторгнутых', 'отмечается', 'отказе', 'останется', 'опасность', 'оно', 'окончена', 'несмотря', 'начиная', 'началась', 'нато', 'направлено', 'москвой', 'манбидж', 'мало', 'мае', 'которые', 'израиль', 'известно', 'избежать', 'иерусалим', 'иг', 'зор', 'зонах', 'заявил', 'затратное', 'затем', 'запрещена', 'западные', 'завершения', 'заботится', 'естественно', 'друзов', 'добиться', 'дейр', 'данностью', 'дамаску', 'дамаска', 'дамаск', 'громить', 'всему', 'воюет', 'восточных', 'войну', 'воздуха', 'влечет', 'видимо', 'африне', 'африна', 'африн', 'артиллерия', 'анкарой', 'алеппо', 'ypg', '6']
# ['электромагнитный анализ', 'штокмановским месторождением', 'четырех стран', 'четко указано', 'точки зрения', 'такую глубину', 'также пункт', 'стороны гренландии', 'стороны аляски', 'столько конфронтация', 'стал опровергать', 'спуск производился', 'соседними странами', 'сергея лаврова', 'семьдесят ),', 'сделать лишь', 'районе арктики', 'принадлежала нам', 'подо льдом', 'первым двоим', 'очень сдержанными', 'основном газоконденсат', 'основании переговоров', 'оно состоялось', 'одной высоте', 'недостижимому газу', 'морскому праву', 'мире меняется', 'министерство геологии', 'мильная зона', 'м году', 'ломоносовском хребте', 'лишь предстоят', 'линиям долготы', 'ледовитый океан', 'лады говорят', 'крайней мере', 'котловине амундсена', 'континентальным шельфом', 'касается переговоров', 'исследовательские работы', 'иной страны', 'именами хиллари', 'имеется положение', 'евгения черняева', 'других местах', 'другими странами', 'дно которой', 'дипломатическом уровне', 'декларативное заявление', 'двух мини', 'глубину 4', 'вопросам сотрудничества', 'владимира груздева', 'будут стоять', 'баренцевом море', 'анатолия сагалевича', '3 километра', '200 миль', '1982 году', '150 километров', '– территория', '– предположительно', 'экспертиза –', 'сравнил это', 'северном полюсе', 'нужна такая', 'научно доказать', 'лишь лет', 'которая простирается', '–', 'это', 'полюсе', 'нужна', 'лет', 'которая', 'доказать', 'этому', 'хотя', 'химический', 'условиях', 'уверен', 'судах', 'связано', 'связанные', 'россией', 'работает', 'работа', 'проходят', 'продвинуть', 'проверить', 'проведена', 'причем', 'появится', 'посмотреть', 'полынью', 'полагаю', 'пока', 'поднявшись', 'погружения', 'поводу', 'определяет', 'однако', 'обстановка', 'нужно', 'норгейма', 'норвегией', 'никто', 'непросто', 'нашло', 'научной', 'насколько', 'ленине', 'который', 'котором', 'компас', 'исследованиям', 'зону', 'знаю', 'западе', 'заметьте', 'заметили', 'доказывает', 'декларирующий', 'границы', 'говорить', 'геополитическое', 'геологический', 'газ', 'востоке', 'востока', 'вопрос', 'бурение', 'бумаге', 'берега', 'арктике', '26']
# ['ян выговский', 'центральном манеже', 'татьяна грауз', 'татьяна виноградова', 'сергей шаргунов', 'саша циммер', 'роман шебалин', 'рама ».', 'пройдет встреча', 'представлен очерк', 'основателем нью', 'новый арбат', 'николай анастасьев', 'написанный прот', 'морфей григорьев', 'михаилом аксеновым', 'марлена мош', 'мария попова', 'марина кудимова', 'максим алпатов', 'людмила вязмитинова', 'лев аннинский', 'лариса волохонская', 'культурном центре', 'константин кокорев', 'клементина ширшова', 'карина гембицкая', 'й этаж', 'ирина михайловека', 'илья семененко', 'елена зейферт', 'екатерина любомирова', 'дмитрий овсянников', 'дмитрий кузьмин', 'глобус »', 'глеб осипов', 'георгий геннис', 'вячеслав куприянов', 'владимир пряхин', 'василий бородин', 'валерия исмиева', 'анна кирилова', 'андрей цуканов', 'андрей семенов', 'анастасия гачева', 'александр скидан', 'александр сенкевич', 'александр марков', 'docx ».', '28 марта', '26 марта', '25 марта', '24 февраля', '23 марта', '22 марта', '– 2', 'др .,', 'др', '2', 'ю', 'участвуют', 'трифонова', 'субботу', 'стр', 'среду', 'спасская', 'сегодня', 'садовая', 'российско', 'пятницу', 'понедельник', 'покровка', 'писателем', 'пироговская', 'пивир', 'начало', 'написано', 'н', 'мясницкая', 'меерсоном', 'м', 'лихачева', 'лесная', 'крупской', 'кор', 'казань', 'доме', 'добролюбова', 'д', 'выступят', 'воскресенье', 'волохонском', 'библиотеке', 'басин', 'б', 'амурская', 'ru', '8', '63', '6', '5', '31', '30', '3', '27', '21', '20', '19', '18', '17', '16', '15', '14', '10', '1', '00']
# ...
# 984    [этих странах, этими альтернативами, электоральных демократий, шансом построить, чаще рассматриваться, хх веке, хронической жертвой, утверждает правду, условиях демократий, упрощенно говоря, университетской среде, украиной управление, удержание власти, трансформации происходили, традиционных площадок, травматического состояния, технократического управления, тех политических, тема разговора, таких случаях, таких масштабах, таким образом, сфер жизни, сумели приподняться, стремятся выбрать, страшно подумать, странах капитализма, стала поспокойнее, стал ссылаться, сравнимых кейсов, способные влиять, сообществом чувства, сообществом интересов, сообщества бессильны, сообщении чувствовался, совершенно бесчувственна, снова обиженные, следующий день, сильными искажениями, сила нравственности, серьезный разговор, сергей аверинцев, своем городе, свободных дискуссий, самодовольной интеллигентщины, сайте gefter, россии )., ренессанс вряд, результаты голосования, результатов голосования, регион ...
# 996    [юрий иосичей, юрий иосич, юрий иосифович, юрий гагарин, юрии ковале, юмор »,, этих анекдотов, шутку шуткой, шевелит )., чувство смешного, чувстве смешного, читать дальше, читательских возрастов, читательский суд, четверо крутят, часовой стрелке, цитировать коваля, цветочный город, художественном тексте, хотел закурить, ушли потихонечку, уйди !», тучку ушло, тоску вгоняет, такому снегу, существующую реально, страна чудес, стран соцлагеря, ставлю точку, срочно заносить, сочинял песни, слава богу, скрипит резина, сказавши загадочно, скажу иначе, синица свистела, серьезно пишет, сергей андреев, сергее михалкове, северных работягах, свое мастерство, свифтовская лапута, самом деле, самое делегату, русской культуры, реке черная, пустые окна, пруд пруди, пространстве сказки, проплывет мимо, приведенном примере, представителя кубы, правильный ответ, правда ль, потолок пробкой, потенциальным правонарушителем, последнего паучка, посвященной вопросу, помню чехословакию, помню болгарию, поздра...
# 997    [ярким солнцем, южной кореи, южной корее, шарунас бартас, четыре дня, человечные истории, фильм сделан, фестивальному кино, фестиваль стал, умеющие обсуждать, украинских событий, тупик жизнь, точная интонация, терзаниях 17, телевизионном шоу, таких событий, такими режиссерами, стали лауреатами, соседних залах, слишком заботясь, синим небом, сильное увлечение, российскими зрителями, раздают призов, раздача призов, разгорается ежегодно, психоаналитический триллер, прошлые годы, программа существует, приобщил публику, принято считать, признан лучшим, преодолевает препятствия, полюбили зрители, полночь »., повседневным мелочам, повернется назвать, петр буслов, ответственным человеком, особенности быта, основная работа, ослабленным зрением, оливье ассайяс, обычному зрителю, общественного устройства, неказенное внимание, недавно поженились, наполненная нежностью, молодая красавица, мечтают спеть, международному конкурсу, матье амальрик, летняя лия, кристоф оноре, которым занимается, кото...
# 998    [экономикой разобрались, экономике значительно, цифровой формат, целостную систему, характере занятости, физической инфраструктуры, участниками сетей, университетскими центрами, угроза должна, традиционные продукты, технологических средствах, тенденциозной интерпретации, твоей спиной, также процессах, суть заключается, стране напряженка, статусном совещании, социальным презрением, совете безопасности, скрытного программно, складывается впечатление, сказки л, серьезную угрозу, самой информации, роль одного, роли программистов, рискуют оказаться, редакторов сми, ранее относилось, разряду тунеядцев, разрешено применение, разработок уделяется, различных сообществ, развития инфосферы, рабочем месте, психологических отношений, прошлой войне, пропагандистского содержания, пропагандистских мероприятий, производители контента, продукции сми, программный продукт, принципиальным вещам, принудительного внедрения, примечательный сюжет, привлекаю внимание, правильно идентифицирована, постоянная ...
# Name: content, Length: 999, dtype: object

# %% [markdown]
# **Эксперимент 4**
# Количество ключевых слов

# %% [markdown]
# **Удается получить 0.17, если сокращаем количество самых частотных слов до 7**, что является сомнительным достижением

# %%
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(7)]))
# Out:
# Precision -  0.15
# Recall -  0.21
# F1 -  0.17
# Jaccard -  0.1

# %% [markdown]
# **Результат 4: немного выше бейслайна, но это, скорее, хак метрики.**

# %%
evaluate(data['keywords'],data['title_norm'].apply(lambda x: x[:10]))
# Out:
# Precision -  0.2
# Recall -  0.13
# F1 -  0.14
# Jaccard -  0.09

# %% [markdown]
# Качество сильно улучшилось! Можно теперь ещё раз посмотреть, что плохого извлекается.

# %%
data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(20)
# Out:
# 0                         [яблоко, молодёжный, который, акция, год, активист, это, деятельность, политика, наш]
# 1                               [миллиард, газа, год, куб, метр, газпром, добыча, 2020, должный, производитель]
# 2                                              [год, это, книга, роман, тот, писать, выйти, один, мир, перевод]
# 3                                    [ким, зинаида, видео, год, журналист, суд, дело, бывший, футиный, который]
# 4                         [площадь, территория, новый, москва, га, который, столица, тинао, парковый, развитие]
# 5                                  [гонка, который, команда, место, позиция, два, один, из-за, круг, чемпионат]
# 6                        [место, влияние, рф, позиция, глава, россия, президент, сергей, политический, рейтинг]
# 7                 [культура, закон, который, сфера, стд, разработать, концепция, проект, изменение, сообщество]
# 8                              [газопровод, сирия, год, турция, газа, россия, европа, катар, который, турецкий]
# 9     [участник, рф, террористический, организация, задержать, цос, четверо, запретить, исламский, государство]
# 10                            [тихон, стихомант, это, журибеда, старик, время, казак, сэмена, говорить, что-то]
# 11                          [жильё, метр, кв, год, миллион, жилищный, население, строительство, спрос, прогноз]
# 12                   [российский, театр, зритель, стать, кино, год, получить, хороший, результат, исследование]
# 13                      [фестиваль, революция, фильм, ленин, награда, хороший, один, сахалин, посмотреть, роль]
# 14                 [вечер, фёдоров, балашов, книга, который, виктория, произведение, женщина, женский, главный]
# 15        [который, сирийский, переговоры, резолюция, оон, франция, сторона, макрон, французский, гуманитарный]
# 16                                 [рф, суд, кс, запрос, постановление, право, человек, бывший, акционер, юкос]
# 17                 [электромобиль, год, тысяча, кобальт, который, компания, аккумулятор, это, автомобиль, цена]
# 18                              [хороший, фильм, оскар, год, один, главный, стать, который, женщина, церемония]
# 19                       [сабина, нюрбургринг, трасса, fia, wtcc, участие, пилотесса, шмитц, гонка, автомобиль]
# Name: content_norm, dtype: object

# %% [markdown]
# Ещё остались некоторые стоп-слова. Вместо того, чтобы расширять список, давайте попробуем выкинуть несуществительные.

# %% [markdown]
# **Эксперимент 5**
# **Извлекаем устойчивые коллокации из текста**

# %%
import nltk
from nltk.collocations import *
ignored_words = nltk.corpus.stopwords.words('russian')
bigram_measures = nltk.collocations.BigramAssocMeasures()

def getcollocations(text):
    proccolls = []
    tokens = nltk.wordpunct_tokenize(text)
    toklem  = [morph.parse(word)[0].normal_form for word in tokens]
    finder = BigramCollocationFinder.from_words(toklem, window_size = 2)
    finder.apply_word_filter(lambda w: len(w) < 3 or w.lower() in ignored_words)
    finder.apply_freq_filter(1)
    colls = finder.nbest(bigram_measures.likelihood_ratio, 10)
    for a in colls:        
        p = morph.parse(a[1])[0]        
        if p and p.tag.gender and 'NOUN' in p.tag:
            p0 = morph.parse(a[0])[0]
            if p0 and 'ADJF' in p0.tag:
                nf  = p0.inflect({'sing', 'nomn', p.tag.gender})
                if nf:
                    proccolls.append(nf.word +" " + a[1])
    return(proccolls)

# %%
# data['content_norm'] = data['content'].apply(normalize)
data['content_colloc'] = data['content'].apply(getcollocations)

# %%
data['title_up'] = data['content_colloc']+data['title_norm']

# %%
# data["content_colloc"]
evaluate(data['keywords'],data['title_up'].apply(lambda x: x[:10]))
# Out:
# Precision -  0.12
# Recall -  0.16
# F1 -  0.13
# Jaccard -  0.08

# %% [markdown]
# **Результат 5: неудачно**

# %% [markdown]
# **Эксперимент 6**
# Отбор слов по части речи

# %%
def normalizepos(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word and word not in stops]
    words = [word.normal_form for word in words if word.tag.POS in ['NOUN']]

    return words

# %%
data['content_norm'] = data['content'].apply(normalizepos)

# %%
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.13
# Recall -  0.25
# F1 -  0.16
# Jaccard -  0.09

# %% [markdown]
# попробуем оставить не только существительные, но и прилагательные

# %%
def normalize4(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word and word not in stops]
    words = [word.normal_form for word in words if word.tag.POS in ['NOUN', 'ADJF']]

    return words

# %%
data['content_norm4'] = data['content'].apply(normalize4)

# %%
evaluate(data['keywords'], data['content_norm4'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.11
# Recall -  0.23
# F1 -  0.15
# Jaccard -  0.08

# %% [markdown]
# **Результат 6: неудачно**

# %% [markdown]
# **Эксперимент 7**
# Попробуем дополнительно выбросить слова, которые часто повторяются, но не оказываются ключевыми

# %%
data['content_norm4'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(20)
# Out:
# 0                       [яблоко, молодёжный, который, акция, год, активист, деятельность, политика, наш, московский]
# 1                                  [миллиард, газа, год, куб, метр, газпром, добыча, производитель, который, страна]
# 2                                        [год, книга, роман, тот, один, мир, перевод, стихотворение, читатель, жанр]
# 3                                         [ким, зинаида, видео, год, журналист, суд, дело, бывший, футиный, который]
# 4                                 [площадь, территория, новый, москва, га, который, столица, тинао, развитие, парка]
# 5                                       [гонка, который, команда, место, позиция, два, один, круг, чемпионат, пилот]
# 6                             [место, влияние, рф, позиция, глава, россия, президент, сергей, политический, рейтинг]
# 7                  [культура, закон, который, сфера, концепция, проект, изменение, сообщество, услуга, общественный]
# 8                                   [газопровод, сирия, год, турция, газа, россия, европа, катар, который, турецкий]
# 9     [участник, рф, террористический, организация, исламский, государство, калужский, область, центр, общественный]
# 10                                     [тихон, стихомант, журибеда, старик, время, казак, сэмена, один, голос, отец]
# 11                            [жильё, метр, год, миллион, жилищный, население, строительство, спрос, прогноз, центр]
# 12                       [российский, театр, зритель, кино, год, хороший, результат, исследование, аудитория, фильм]
# 13                              [фестиваль, революция, фильм, ленин, награда, хороший, один, сахалин, роль, миронов]
# 14                      [вечер, фёдоров, балашов, книга, который, виктория, произведение, женщина, женский, главный]
# 15             [который, сирийский, переговоры, резолюция, оон, франция, сторона, макрон, французский, гуманитарный]
# 16                                 [рф, суд, запрос, постановление, право, человек, бывший, акционер, юкос, решение]
# 17                      [электромобиль, год, тысяча, кобальт, который, компания, аккумулятор, автомобиль, цена, том]
# 18                                    [хороший, фильм, оскар, год, один, главный, который, женщина, церемония, свой]
# 19               [сабина, нюрбургринг, трасса, участие, пилотесса, шмитц, гонка, автомобиль, организатор, чемпионат]
# Name: content_norm4, dtype: object

# %%
morestops = {"год", "страна", "главный", "развитый", "март", "сегодня", "бумажный", "нынешний", "назад", "популярный"} | stops
def normalize23(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word]
    words = [word.normal_form for word in words if word.tag.POS in ['NOUN', 'ADJF'] and word.normal_form not in morestops]

    return words

# %%
data['content_norm23'] = data['content'].apply(normalize23)

# %%
evaluate(data['keywords'], data['content_norm23'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.12
# Recall -  0.23
# F1 -  0.15
# Jaccard -  0.09

# %%
data['content_norm23'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(20)
# Out:
# 0                            [яблоко, молодёжный, который, акция, активист, деятельность, свой, политика, весь, наш]
# 1                      [миллиард, газа, куб, метр, газпром, добыча, производитель, который, независимый, внутренний]
# 2                                  [весь, книга, роман, мир, перевод, стихотворение, читатель, жанр, поэзия, работа]
# 3                                       [ким, зинаида, видео, журналист, суд, дело, бывший, футиный, который, рубль]
# 4                                 [площадь, территория, новый, москва, га, который, столица, тинао, развитие, парка]
# 5                            [гонка, который, команда, место, позиция, круг, чемпионат, пилот, последний, следующий]
# 6                             [место, влияние, рф, позиция, глава, россия, президент, сергей, политический, рейтинг]
# 7                  [культура, закон, который, сфера, концепция, проект, изменение, сообщество, услуга, общественный]
# 8                                 [газопровод, сирия, турция, газа, россия, европа, катар, который, турецкий, поток]
# 9     [участник, рф, террористический, организация, исламский, государство, калужский, область, центр, общественный]
# 10                                     [тихон, стихомант, журибеда, старик, время, казак, сэмена, голос, отец, весь]
# 11                           [жильё, метр, миллион, жилищный, население, строительство, спрос, прогноз, центр, рост]
# 12             [российский, театр, зритель, кино, хороший, результат, исследование, аудитория, фильм, петербургский]
# 13                              [фестиваль, революция, фильм, ленин, награда, хороший, сахалин, роль, свой, миронов]
# 14                        [вечер, фёдоров, балашов, книга, который, виктория, произведение, женщина, женский, елена]
# 15             [который, сирийский, переговоры, резолюция, оон, франция, сторона, макрон, французский, гуманитарный]
# 16                                 [рф, суд, запрос, постановление, право, человек, бывший, акционер, юкос, решение]
# 17         [электромобиль, тысяча, кобальт, который, компания, аккумулятор, автомобиль, цена, агентство, электрокар]
# 18                                [хороший, фильм, весь, оскар, который, женщина, свой, церемония, статуэтка, актёр]
# 19               [сабина, нюрбургринг, трасса, участие, пилотесса, шмитц, гонка, автомобиль, организатор, чемпионат]
# Name: content_norm23, dtype: object

# %% [markdown]
# **Результат 7**
# Тоже без особого успеха

# %% [markdown]
# <hr>

# %% [markdown]
# Ещу улучшения!

# %%
data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(10)
# Out:
# 0        [яблоко, акция, год, активист, деятельность, политика, власть, задача, молодая, человек]
# 1               [миллиард, газа, год, куб, метр, газпром, добыча, производитель, страна, прогноз]
# 2                [год, книга, роман, мир, перевод, стихотворение, читатель, жанр, поэзия, работа]
# 3                     [ким, зинаида, видео, год, журналист, суд, дело, рубль, процесс, заседание]
# 4                   [площадь, территория, москва, га, столица, тинао, развитие, парка, парк, год]
# 5                    [гонка, команда, место, позиция, круг, чемпионат, пилот, бокс, заезд, льюис]
# 6               [место, влияние, рф, позиция, глава, россия, президент, сергей, рейтинг, участие]
# 7    [культура, закон, сфера, концепция, проект, изменение, сообщество, услуга, учреждение, дело]
# 8                    [газопровод, сирия, год, турция, газа, россия, европа, катар, поток, проект]
# 9                 [участник, рф, организация, государство, область, центр, связь, фсб, март, год]
# Name: content_norm, dtype: object

# %% [markdown]
# Не очень значимые слова все ещё остались. Давайте попробуем отсеять стоп-слова с помощью tfidf.

# %% [markdown]
# Воспользуемся TfidfVectorizer.

# %%
data['content_norm_str'] = data['content_norm'].apply(' '.join)

# %%
# можно заодно сделать нграммы
tfidf = TfidfVectorizer(ngram_range=(1,2), min_df=5)

# %%
tfidf.fit(data['content_norm_str'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

# %% [markdown]
# Преобразуем наши тексты в векторы, где на позиции i стоит tfidf коэффициент слова i из словаря.

# %%
texts_vectors = tfidf.transform(data['content_norm_str'])

# %% [markdown]
# Отсортируем векторы текстов по этим коэффициентам и возьмем топ-10.

# %%
# сортировка по убыванию, поэтому нужно развернуть список
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-11:-1]]

# %%
keywords[:3]
# Out:
# [['яблоко',
#   'активист',
#   'акция',
#   'дарья',
#   'деятельность',
#   'молодая человек',
#   'политика',
#   'виктор',
#   'выборы',
#   'силовик'],
#  ['миллиард куб',
#   'куб метр',
#   'куб',
#   'газпром',
#   'газа',
#   'миллиард',
#   'добыча',
#   'метр',
#   'добыча газа',
#   'холдинг'],
#  ['роман',
#   'книга',
#   'жанр',
#   'стихотворение',
#   'перевод',
#   'читатель',
#   'год',
#   'поэзия',
#   'произведение',
#   'том']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.12
# Recall -  0.24
# F1 -  0.15
# Jaccard -  0.09

# %% [markdown]
# Результат ещё немного улучшился. Немного подросла точность. Теперь вместо стоп-слов в ключевые попадают имена и все такое. Иногда это хорощо, а иногда нет (собянин - может быть ключевым словом, а дарья - вряд ли)

# %% [markdown]
# Возьмем этот результат за baseline.

# %% [markdown]
# Precision -  0.13
# Recall -  0.24
# F1 -  0.16
# Jaccard -  0.09

# %% [markdown]
# ***Эксперимент 8***

# %% [markdown]
# **Объединяем результаты отбора по TfIdf с коллокациями**

# %%
data["kw"] = keywords

# %%
data["both"] = data["kw"]+data["content_colloc"]

# %%
evaluate(data['keywords'], data["both"])
# Out:
# Precision -  0.1
# Recall -  0.27
# F1 -  0.14
# Jaccard -  0.08

# %% [markdown]
# **Результат 8: неудачно**

# %% [markdown]
# **Эксперимент 9**
# Попробуем поменять параметра TfIdfVectorizer

# %%
tfidf2 = TfidfVectorizer(ngram_range=(1,2), min_df=2)
tfidf2.fit(data['content_norm_str'])
id2word2 = {i:word for i,word in enumerate(tfidf.get_feature_names())}
texts_vectors2 = tfidf2.transform(data['content_norm_str'])
keywords2 = [[id2word2[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-11:-1]] 
evaluate(data['keywords'], keywords2)
# Out:
# Precision -  0.12
# Recall -  0.24
# F1 -  0.15
# Jaccard -  0.09

# %% [markdown]
# **Результат 9: неудачно**

# %% [markdown]
# ## Попробуем графы!

# %% [markdown]
# Большая часть методов для извлечения ключевых слов основана на применении графов. Основная идея - каким-то образом перевести текст в граф, а затем каким-то образом расчитать важность каждого узла и вывести топ-N самых важных узлов.
#
# Перевод текста в граф -  не тривиальная задача. Часто применяют такой подход - построим матрицу совстречаемости слов (в каком-то окне), эта матрица будет нашей матрицей смежности.

# %% [markdown]
# Для выбора важных узлов часто используют простой randow walk. Алгоритм примерно такой:
# 1) Каким-то образом выбирается первый узел графа (например, случайно из равномерного распределения)
# 2) на основе связей этого узла с другими, выбирается следующий узел
# 3) шаг два повторяется некоторое количество раз (например, тысячу) __*чтобы не зацикливаться, с какой-то вероятностью мы случайно перескакиваем на другой узел (даже если он никак не связан с текущим, как в шаге 1)__
# 5) на каждом шаге мы сохраняем узел в котором находимся
# 6) в конце мы считаем в каких узлах мы были чаще всего и выводим top-N
#
#
# Предполагается, что мы часто будем приходить в важные узлы графа.

# %%
from itertools import combinations

# %% [markdown]
# Для наглядности реализуем этот подход без networkx.

# %%
def get_kws(text, top=5, window_size=5, random_p=0.1):

    vocab = set(text)
    word2id = {w:i for i, w in enumerate(vocab)}
    id2word = {i:w for i, w in enumerate(vocab)}
    # преобразуем слова в индексы для удобства
    ids = [word2id[word] for word in text]

    # создадим матрицу совстречаемости
    m = np.zeros((len(vocab), len(vocab)))

    # пройдемся окном по всему тексту
    for i in range(0, len(ids), window_size):
        window = ids[i:i+window_size]
        # добавим единичку всем парам слов в этом окне
        for j, k in combinations(window, 2):
            # чтобы граф был ненаправленный 
            m[j][k] += 1
            m[k][j] += 1
    
    # нормализуем строки, чтобы получилась вероятность перехода
    for i in range(m.shape[0]):
        m[i] /= np.sum(m[i])
    
    # случайно выберем первое слова, а затем будет выбирать на основе полученых распределений
    # сделаем так 5 раз и добавим каждое слово в счетчик
    # чтобы не забиться в одном круге, иногда будет перескакивать на случайное слово
    
    c = Counter()
    # начнем с абсолютного случайно выбранного элемента
    n = np.random.choice(len(vocab))
    for i in range(500): # если долго считается, можно уменьшить число проходов
        
        # c вероятностью random_p 
        # перескакиваем на другой узел
        go_random = np.random.choice([0, 1], p=[1-random_p, random_p])
        if go_random:
            n = np.random.choice(len(vocab))
        
        n = take_step(n, m)
        # записываем узлы, в которых были
        c.update([n])
    
    # вернем топ-N наиболее часто встретившихся сл
    return [id2word[i] for i, count in c.most_common(top)]

def take_step(n, matrix):
    rang = len(matrix[n])
    # выбираем узел из заданного интервала, на основе распределения из матрицы совстречаемости
    next_n = np.random.choice(range(rang), p=matrix[n])
    return next_n

# %%
# %%time
keywords_rw = data['content_norm'].apply(lambda x: get_kws(x, 10, 10))
# Out:
# Wall time: 1min 31s

# %%
evaluate(data['keywords'], keywords_rw)
# Out:
# Precision -  0.11
# Recall -  0.21
# F1 -  0.13
# Jaccard -  0.08

# %%
keywords_rw.head(10)
# Out:
# 0                       [яблоко, год, власть, акция, активист, молодёжь, политика, россия, убийство, школа]
# 1                       [год, миллиард, газа, газпром, добыча, метр, производитель, куб, население, страна]
# 2                                   [книга, роман, год, идея, рука, стих, удовольствие, жанр, мир, перевод]
# 3                     [ким, экспертиза, зинаида, видео, дело, журналист, заседание, монтаж, склейка, слово]
# 4                               [площадь, парка, га, территория, москва, парк, развитие, регион, зона, год]
# 5                                [гонка, команда, позиция, пилот, бокс, место, сезон, сутил, трасса, заезд]
# 6                            [место, влияние, рф, позиция, глава, президент, сергей, число, лидер, участие]
# 7    [культура, закон, учреждение, концепция, проект, союз, законодательство, система, разработка, человек]
# 8                       [турция, газопровод, россия, катар, поток, европа, сирия, газа, строительство, год]
# 9                       [участник, рф, организация, государство, фсб, связь, центр, год, область, исламист]
# Name: content_norm, dtype: object

# %% [markdown]
# Попбруем теперь важность считать с помощью какой-нибудь метрики из networkx.

# %%
import networkx as nx

# %%
def build_matrix(text, window_size=5):
    vocab = set(text)
    word2id = {w:i for i, w in enumerate(vocab)}
    id2word = {i:w for i, w in enumerate(vocab)}
    # преобразуем слова в индексы для удобства
    ids = [word2id[word] for word in text]

    # создадим матрицу совстречаемости
    m = np.zeros((len(vocab), len(vocab)))

    # пройдемся окном по всему тексту
    for i in range(0, len(ids), window_size):
        window = ids[i:i+window_size]
        # добавим единичку всем парам слов в этом окне
        for j, k in combinations(window, 2):
            # чтобы граф был ненаправленный 
            m[j][k] += 1
            m[k][j] += 1
    
    return m, id2word

def some_centrality_measure(text, window_size=3, topn=5):
    
    matrix, id2word = build_matrix(text, window_size)
    G = nx.from_numpy_array(matrix)
    # тут можно поставить любую метрику
    node2measure = dict(nx.pagerank(G))
    
    return [id2word[index] for index,measure in sorted(node2measure.items(), key=lambda x: -x[1])[:topn]]

# %%
# %%time
keyword_nx = data['content_norm'].apply(lambda x: some_centrality_measure(x, 10, 10))
# Out:
# Wall time: 2min 32s

# %%
evaluate(data['keywords'], keyword_nx)
# Out:
# Precision -  0.12
# Recall -  0.24
# F1 -  0.15
# Jaccard -  0.09

# %% [markdown]
# Результаты не превосходят tfidf, но и не сильно уступают. Явно можно что-то доработать и превзойти baseline.

# %% [markdown]
# Готовое решение есть в gensim. Давайте попробуем его.

# %%
from gensim.summarization import keywords
# Out:
# c:\python36\lib\site-packages\gensim\utils.py:862: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %%
gensim_kws = data['content_norm'].apply(lambda x: keywords(' '.join(x)).split('\n')[:10])

# %%
evaluate(data['keywords'], gensim_kws)
# Out:
# Precision -  0.07
# Recall -  0.11
# F1 -  0.08
# Jaccard -  0.04

# %% [markdown]
# Наша имплементация отработала получше.

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# В семинаре установлен такой бейзлан - F1 -  0.16 (не будем учитывать точность и полноту по отдельности и отбросим жаккара).

# %% [markdown]
# **Ваша задача - предложить 3 способа побить бейзлайн. **

# %% [markdown]
# Нет никаких ограничений кроме:
#
# 1) нельзя изменять метрику
# 2) решение должно быть воспроизводимым

# %% [markdown]
# В качестве ответа нужно предоставить jupyter тетрадку с экспериментами (обязательное условие!) и описать каждую из идей в форме - https://goo.gl/forms/H9lBH9wCxqq1T0ru2

# %% [markdown]
# Каждый реализованный и описанный способ оценивается в 3 балла. Дополнительный балл можно получить, если способы затрагивают разные аспекты решения (например, первая идея - улучшить нормализацию, вторая - улучшить способ представления текста в виде графа, третья - предложить способ удаления из топа идентичных ключевых слов (рф, россия)).

# %% [markdown]
# Можно использовать мой код как основу, а можно придумать что-то полностью другое.

# %% [markdown]
# Если у вас никак не получается побить бейзлайн вы можете предоставить реализацию и описание неудавшихся экспериментов (каждый оценивается в 1 балл).
